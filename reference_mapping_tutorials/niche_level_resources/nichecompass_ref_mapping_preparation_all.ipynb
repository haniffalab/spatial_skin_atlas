# %%
"""
A full tutorial is available here:
https://nichecompass.readthedocs.io/en/latest/tutorials/notebooks/mouse_cns_spatial_reference_mapping.html

Here we illustrate preaparation of our core dataset as a reference for mapping the validation data
"""
# Out:
# '\nA full tutorial is available here:\nhttps://nichecompass.readthedocs.io/en/latest/tutorials/notebooks/mouse_cns_spatial_reference_mapping.html\n\nHere we illustrate preaparation of our core dataset as a reference for mapping the validation data\n'

# %%
import os, sys
import random
import warnings
import logging
from datetime import datetime
# import gdown
import anndata as ad
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sp
import seaborn as sns
import squidpy as sq
#from matplotlib import gridspec
#from sklearn.preprocessing import MinMaxScaler
from re import sub
import numpy as np
import pickle

# from nichecompass.models import NicheCompass
# from nichecompass.utils import (add_gps_from_gp_dict_to_adata,
#                                 create_new_color_dict,
#                                 compute_communication_gp_network,
#                                 visualize_communication_gp_network,
#                                 extract_gp_dict_from_mebocost_ms_interactions,
#                                 #extract_gp_dict_from_mebocost_es_interactions,
#                                 extract_gp_dict_from_nichenet_lrt_interactions,
#                                 extract_gp_dict_from_omnipath_lr_interactions,
#                                 #filter_and_combine_gp_dict_gps,
#                                 filter_and_combine_gp_dict_gps_v2,
#                                 generate_enriched_gp_info_plots)


# %%
# Out:
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/numba/core/decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Set output dir + where to find niche compass files

# %%
"""
make sure inside this path, you have the folders gene_annotations 
and gene_programs with the files
(available from https://github.com/Lotfollahi-lab/nichecompass/tree/main/data)
"""

handle='/lustre/scratch124/cellgen/haniffa/projects/developmental_fibroblasts/nobackup_output/nichecompasss/nichecompass/'

# %% [markdown]
# # Choose number of SVGs to reduce dataset to

# %%
n_svg=2048
n_neighbors = 8

# %% [markdown]
# # Set up reference and query (important part)

# %%
# """
# load adata (includes reference and query)
# - note that sample id is in adata.obs["Sample"]
# - cell type is in adata.obs["Annotation"]

# if using our adata as reference, then either:
# 1. remove all query samples (in query_batches below), or
# 2. add query samples to reference_batches, 

# and then add your sample id's to query_batches
# """

# #ADATA_PATH= '/lustre/scratch126/cellgen/lotfollahi/ls34/nemo/adata_all.h5ad.clustered.clustered10.good.prenichecompass'
# #'/nfs/team298/ls34/xenium_atlas/model_ALL_CLEAN_scanvi_ALL/adata_counts_integrated_final_colored.h5ad'
# #ADATA_PATH = '/nfs/team298/ls34/adult_skin/final_adatas/adata_combined_new.h5ad.final.filtered'


# SAVE_PATH='/lustre/scratch124/cellgen/haniffa/projects/beacon/nobackup_data/adata_all_xenium.h5ad'
# for x in adata_all.obs.columns:
#     adata_all.obs[x]=adata_all.obs[x].astype(str)
# adata_all.write(SAVE_PATH)

# adata_vis=sc.read_h5ad(ADATA_PATH)  
# adata_vis=adata_vis[adata_vis.obs["tech"]=="xenium"].copy()

# %%
SAVE_PATH='/lustre/scratch124/cellgen/haniffa/projects/beacon/nobackup_data/adata_all_xenium.h5ad'
adata=sc.read_h5ad(SAVE_PATH)
adata.obs["sample"]=adata.obs["info_id6"]
adata.obs.info_id6.value_counts()
# Out:
# info_id6
# Melanoma                                                              98602
# 3D_BK25_week12-D2                                                     41325
# output-XETG00495__0068445__13871-JF-1_ROI-7__20250821__165859         40024
# output-XETG00272__0021042__AX29-SKI-0-FO-1-S4__20240815__114049       36882
# output-XETG00155__0032957__AX38-SKI-0-FO-1-S3-B1__20241217__145711    33391
#                                                                       ...
# Baseline_resolved_CE4-SKI-27-FO-1-S22-B2                               5642
# BK20_Day 14                                                            5628
# Baseline_resolved_CE4-SKI-27-FO-1-S22_replicate                        5477
# BK25_Day 14                                                            3038
# BK20_Lesional Baseline                                                 2290
# Name: count, Length: 187, dtype: int64

# %%
adata.obs.info_id6.isna().sum()
# Out:
# 0

# %%
# adata.obs["dataset_id2"].value_counts()

# %%
adata.obs["Site_status"].value_counts()
# Out:
# Site_status
# nan                                         488404
# Lesional                                    276430
# Week 12                                     231018
# Non-lesional                                209578
# 3D_Week12                                   180311
# Relapse                                     180060
# 3D_Lesional_baseline                        153479
# Remission_longterm (past)                   140285
# Remission_longterm (never)                  127032
# Melanoma                                     98602
# AD                                           90550
# relapse                                      76358
# Psoriasis_replicate_non-lesional             76048
# Week 8 Psoriasis                             72094
# No disease signs (at time of relapse)        71279
# Psoriasis_replicate_Lesional                 60647
# Healthy                                      59315
# Psoriasis_replicate_PostRx                   49385
# Interval timepoint                           38364
# Psoriasis                                    37887
# Day 14_HF                                    30438
# BK50_wk4 Relapse                             24857
# BK49_Past Lesional wk4 Relapse               19969
# Week 4 (resolved)_CE5-SKI-27-FO-3-S22-D1     19360
# BK20_Day 3                                   17989
# BK27_Day 3                                   14554
# BK18_Day 3                                   14274
# BK43_wk4 Relapse                             14035
# BK18_Day 14                                  13434
# BK46_wk4 Relapse                             13244
# BK51_Past Lesional wk4 Relapse               12503
# Week 4 (resolved)_CE6-SKI-28-FO-2-S22-D2     11658
# BK22_Day 3                                   11214
# BK39_Day 14                                  10775
# BK21_Day 14                                  10438
# BK24_Day 3                                   10146
# BK24_Day 14                                   9843
# Relape                                        9713
# BK25_Day 3                                    9493
# BK22_Day 14                                   9007
# BK21_Day 3                                    8944
# BK39_Day 3                                    8475
# BK27_Day 14                                   8420
# BK23_Day 3                                    8160
# BK23_Day 14                                   7691
# BK30_Day 3                                    7345
# BK20_Day 14                                   5628
# BK25_Day 14                                   3038
# Name: count, dtype: int64

# %%
adata.obs["Patient_status"].value_counts()
# Out:
# Patient_status
# AD                       1288286
# Psoriasis                 365221
# relapse                   242073
# mintflowrevision_todo     203397
# nan                       186080
# 3d_Lesional_baseline      175557
# HS                        175057
# 3d_Week12                 158233
# prurigo                   109950
# Melanoma                   98602
# Healthy                    59315
# Name: count, dtype: int64

# %%
# # RENAME = {'Week 8 (resolved)_CE6-SKI-28-FO-3-S22_replicate': 'AD',
# #  'Baseline_never_CE5-SKI-27-FO-2-S22_replicate': 'Psoriasis',
# #  'Baseline_resolved_CE3-SKI-28-FO-1-S22_replicate': 'Psoriasis',
# #  'Baseline_resolved_CE6-SKI-20-FO-1-S22_replicate': 'Psoriasis',
# #  'Lesional_CE6-SKI-28-FO-4-S22_replicate': 'Psoriasis',
# #  'Lesional_CE4-SKI-27-FO-4-S22_replicate': 'Psoriasis',
# #  'Week 8 (resolved)_CE5-SKI-27-FO-4-S22_replicate': 'Psoriasis',
# #  'Baseline_resolved_CE6-SKI-28-FO-4-S22_replicate': 'Psoriasis',
# #  'Lesional_CE5-SKI-28-FO-1-S22_replicate': 'Psoriasis',
# #  'Baseline_resolved_CE4-SKI-27-FO-1-S22_replicate': 'Psoriasis',
# #  'Week 8 (resolved)_CE3-SKI-28-FO-4-S22_replicate': 'Psoriasis',
# #  'Week 8 (resolved)_CE4-SKI-27-FO-3-S22_replicate': 'Psoriasis',
# #  'Lesional_Baseline_resolved_CE3-SKI-24-FO-1-S22_replicate': 'Psoriasis',
# #  'Baseline_never_CE3-SKI-28-FO-2-S22_replicate': 'Psoriasis',
# #  'Baseline_resolved_CE5-SKI-27-FO-1-S22_replicate': 'Psoriasis',
# #  'Baseline_never_CE4-SKI-21-FO-1-S22_replicate': 'Psoriasis',
# #  'output-XETG00335__00728669__BK21-SKI-27-FO-1-S8-A3_BK51-SKI-27-FO-2-S9-B2__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK23-SKI-27-FO-1-S8-B1__20250826__123231': 'AD',
# #  'output-XETG00335__00728669__BK21-SKI-27-FO1-S11-C1__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK27-SKI-27-FO-5-S9-D1__20250826__123231': 'AD',
# #  'output-XETG00335__00728669__CE3-SKI-28-FO-1-S25-E1__20250826__123231': 'Psoriasis',
# #  'output-XETG00335__00728669__BK21-SKI-27-FO-1-S13-C2_CE3-SKI-28-FO-1-S28-D2__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK22-SKI-27-FO-2-S7-A1__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK30-SKI-28-FO-1-S6-B2__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK39-SKI-27-FO-1-S8-D2__20250826__123231': 'AD',
# #  'output-XETG00335__00728669__CE3-SKI-28-FO-1-S25-D1__20250826__123231': 'Psoriasis',
# #  'output-XETG00335__0072771__BK30-SKI-28-FO-1-S14-C2__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK27-SKI-27-FO-1-S6-C1__20250826__123231': 'AD',
# #  'output-XETG00335__00728669__CE4-SKI-27-FO-1-S25-S29-S32__20250826__123231': 'Psoriasis',
# #  'output-XETG00335__00728669__BK51-SKI-27-FO-2-S4-S8-S6__20250826__123231': 'AD',
# #  'output-XETG00335__0072771__BK23-SKI-27-FO-5-S9-A2__20250826__123231': 'AD'}
# # adata_i.obs["Patient_status"]=adata_i.obs["sample_id"].map(RENAME).fillna(adata_i.obs["Patient_status"])
# RENAME = {'AD': 'AD',
#  'Psoriasis': 'Psoriasis',
#  'Healthy': 'Healthy',
#  '3d_Lesional_baseline': 'AD',
#  '3d_Week12': 'AD',
#  'relapse': 'AD_relapse',
#  'HS': 'HS',
#  'Melanoma': 'Melanoma',
#  'mintflowrevision_todo': 'AD',
#  'ffpe_todo': 'AD'}
# adata_i.obs["Patient_status"]=adata_i.obs["Patient_status"].map(RENAME)#.fillna(adata_i.obs["Patient_status"])

# %%
# STOP

# %%
adata.obs["Annotation"]=adata.obs["lvl5_annotation"]
adata.obs["Annotation"].value_counts()
# Out:
# Annotation
# nan                        506794
# KC3                        315166
# New/unlabelled/excluded    285007
# KC1                        216177
# F2: Universal              193174
#                             ...
# Neutrophil                     21
# Cartilage                      13
# ILC_Prolif                     12
# Mac_CX3CR1+                    12
# ILC1_NCR2+P2RX7+               11
# Name: count, Length: 106, dtype: int64

# %%
adata.obs["sample"]=adata.obs["info_id6"]

# %%
# adata_vis=ad.concat([adata_vis, adata],
#                    label="batch_nc",
#                     keys=["reference", "query"],
#                     join="outer"
#                    )
#{x:x for x in adata.obs["dataset_id2"].unique()}
RENAME = {'HS': 'query',
 'Melanoma': 'query',
 'AD_mintflow': 'query',
 'beacon_ffpe': 'query',
 'beacon_valid': 'query',
 'beacon': 'reference',
 'beacon_interval_time': 'query',
          'prurigo': 'query'}
adata.obs["batch_nc"]=adata.obs["dataset_id"].map(RENAME)
adata_vis=adata

# %%
adata.obs["batch_nc"].isna().sum()
# Out:
# 76358

# %%
adata_vis.obs["sample"]=adata_vis.obs["info_id6"]
adata_vis.obs["sample"].value_counts()
# Out:
# sample
# Melanoma                                                              98602
# 3D_BK25_week12-D2                                                     41325
# output-XETG00495__0068445__13871-JF-1_ROI-7__20250821__165859         40024
# output-XETG00272__0021042__AX29-SKI-0-FO-1-S4__20240815__114049       36882
# output-XETG00155__0032957__AX38-SKI-0-FO-1-S3-B1__20241217__145711    33391
#                                                                       ...
# Baseline_resolved_CE4-SKI-27-FO-1-S22-B2                               5642
# BK20_Day 14                                                            5628
# Baseline_resolved_CE4-SKI-27-FO-1-S22_replicate                        5477
# BK25_Day 14                                                            3038
# BK20_Lesional Baseline                                                 2290
# Name: count, Length: 187, dtype: int64

# %%
adata_vis.obs["Annotation"].value_counts()
# Out:
# Annotation
# nan                        506794
# KC3                        315166
# New/unlabelled/excluded    285007
# KC1                        216177
# F2: Universal              193174
#                             ...
# Neutrophil                     21
# Cartilage                      13
# ILC_Prolif                     12
# Mac_CX3CR1+                    12
# ILC1_NCR2+P2RX7+               11
# Name: count, Length: 106, dtype: int64

# %%
"""
SPLIT INTO REFERENCE AND QUERY
"""
 
"""
replace these query batches with your samples
"""
query_batches = adata[adata.obs["batch_nc"]=="query"].obs["sample"].unique().to_list()


reference_batches = [x for x in adata_vis.obs["sample"].unique() if x not in query_batches]
# Out:
# /tmp/ipykernel_2079761/3494869091.py:8: FutureWarning: Categorical.to_list is deprecated and will be removed in a future version. Use obj.tolist() instead
#   query_batches = adata[adata.obs["batch_nc"]=="query"].obs["sample"].unique().to_list()

# %%
# adata_vis.obs["batch_nc"] = "query"
# adata_vis.obs.loc[adata_vis.obs["sample"].isin(reference_batches), "batch_nc"] = "reference"

# %%
adata_vis.layers["counts"]=adata_vis.X.copy()

# %%
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 3061771 × 5178
#     obs: 'sample_id', 'barcode', 'GSE', 'Site_status', 'Patient_status', 'Location', 'Age', 'Sex', 'dataset_id', 'lvl5_annotation', 'atlas_status', 'atlas_status_reynolds', 'Timepoint', 'info_id6', 'tech', 'scanvi_predictions2', 'lvl1_new', 'Site_status_binary2', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id_dir', 'patient_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'Mapping_status', 'scanvi_predictions', 'broad_annotation', 'fine_annotations', 'fine_annotation', 'disease', 'tmp', 'broad_celltypes', 'tech2', 'time_direction', 'fine_celltypes', 'region', 'celltype', 'DonorID', 'niche_name', 'info_id', 'leiden_res1', 'leiden_res2', 'original_celltypes', 'n_genes', 'NICHE_NAMES', 'leiden_res0.5', 'spatial_niche', 'sample_id2', 'xenium_id', 'xenium_id_recoded', 'sample_id_original', 'timepoint', 'drug', 'responder', 'new_annotation', '6m_easi', 'baseline_easi', 'response', 'Sanger patient ID', 'GSTT patient ID', 'Drug', 'Responder', "Library type (CITE or 5'GEX/TCR)", 'Segmentation Y/N?', 'Sample ID', 'Xenium slide number', 'Xenium region number2', 'baseline_postrx', 'Annotation', 'batch', 'new_annotation2', 'new_annotation3', 'annotation_new4', 'new_annotation4', 'new_annotation5', 'new_annotation6', 'sample', 'veryfine_celltypes_new', 'niche_category', 'veryfine_celltypes_new2', 'lvl1', 'lvl0', 'veryfine_celltypes_new3', 'veryfine_celltypes_new4', 'test', 'veryfine_celltypes_new5', 'veryfine_celltypes_new5_incprolif', 'veryfine_celltypes', 'fine_celltypes_new', 'mod_celltypes_new', 'broad_celltypes_new', 'Site_status_binary', 'lvl4_annotation', 'number', 'lvl3_annotation', 'disease_overall', 'lvl0_annotation', 'lvl0_annotation2', 'lvl1_annotation', 'lvl1_annotation2', 'lvl1_annotation3', 'lvl1_annotation4', 'lvl1_annotation5', 'lvl1_annotation6', 'lvl1_annotation7', 'lvl1_annotation8', 'lvl2_annotation9', 'Annotation_tomap', 'leiden_res3', 'lvl3_annotation3', 'lvl3_annotation4', 'lvl3_annotation5', 'combined_annotation', 'combined_annotation2', 'lvl5_annotation_new3', 'lvl0_new', 'combined_annotation3', 'combined_annotation4', 'combined_annotation6', 'combined_annotation7', 'combined_annotation8', 'combined_annotation9', 'final_annotation', 'final_annotation2', 'final_annotation3', 'final_annotation4', 'final_annotation5', 'final_annotation7', 'final_annotation8', 'final_annotation9', 'final_annotation10', 'final_annotation_lvl5temp', 'niche_names', 'niche10', 'info_id2', 'final_annotation_lvl4', 'final_annotation_lvl3', 'niche11', 'final_annotation5_3', 'final_annotation5_2', 'final_annotation_lvl5_4', 'FinalXeniumScanVI_14', 'leiden_res0.1', 'FinalXeniumScanVI_16', 'FinalXeniumScanVI_17', 'niche12', 'lvl2_annotation', 'Timepoint2', 'Site_status_simple', 'updatenames1', 'updatenames2', 'updatenames3', 'lvl5_annotation_new', 'lvl5_annotation_new2', 'lvl5_annotation_new4', 'lvl5_annotation_new5', 'lvl5_annotation_new_preophan', 'lvl5_annotation_new9', 'lvl5_annotation_new12', 'lvl5_annotation_new13', 'baseline_severity', 'temp', 'lvl4_annotation_sept', 'prep', 'Site_status_archive', 'response_binned', 'xenium_id_recoded2', 'RUN_ID', 'newintegration', 'leiden_res0.2', 'replicate_id', 'fig8_mapping', 'all_vs_core', 'sample_id_nemo', 'leiden_res4', 'niche14', 'provisional', 'provisional2', 'atlas_status_simple', 'niche19', 'data_addition', 'fig1a_numbers_scrna', 'fig1_numbers_xenium_without_validation_data', 'Site_status2', 'info_id6_recode', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'QC_hi', 'QC_mid', 'l ...
#     obsm: 'X_scanvi', 'X_scvi', 'X_umap', 'cell_emb', 'neighborhood_emb', 'spatial'
#     layers: 'X_count', 'X_rank', 'counts'

# %%
query_check = list(adata_vis[adata_vis.obs["batch_nc"]=="query"].obs["sample"].unique())
for x in query_batches:
    if x not in query_check:
        raise ValueError(f"Batch '{x}' not found in query samples.")

# %%
reference_batches= list(adata_vis[adata_vis.obs["batch_nc"]=="reference"].obs["sample"].unique())
query_batches= list(adata_vis[adata_vis.obs["batch_nc"]=="query"].obs["sample"].unique())

# %%
all_batches = reference_batches +query_batches

# %%
adata_vis.obs["batch_nc"].isna().sum()
# Out:
# 76358

# %%
### from jimmy lee 
def select_slide2(adata, s, s_col='sample'):
    """ This function selects the data for one slide from the spatial anndata object.
    :param adata: Anndata object with multiple spatial experiments
    :param s: name of selected experiment
    :param s_col: column in adata.obs listing experiment name for each location
    """
    slide = adata[adata.obs[s_col].isin([s]), :]
#     s_keys = list(slide.uns['spatial'].keys())
#     s_spatial = np.array(s_keys)[[s in k for k in s_keys]][0]
#     slide.uns['spatial'] = {s_spatial: slide.uns['spatial'][s_spatial]}
    return slide

# %%
spatial_key = "spatial"

adj_key = "spatial_connectivities"

adata_batch_list = []
print("Processing reference batches...")
for batch in all_batches:
    print(f"Processing batch {batch}...")
    print("Loading data...")
    adata_batch = select_slide2(adata_vis, batch)
    print(f"Size {adata_batch.shape}")
    print("Computing spatial neighborhood graph...\n")
    # Compute (separate) spatial neighborhood graphs
    logging.info("sq.gr.spatial_neighbors")
    
    coords = adata_batch.obsm[spatial_key]
    if np.isnan(coords).any():
        print("NaN detected in spatial coordinates, reconstructing from centroids...")
        if 'x_centroid' in adata_batch.obs and 'y_centroid' in adata_batch.obs:
            adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
            print(f"Reconstructed coordinates from centroids")
        else:
            print("No centroid columns found, removing cells with NaN coords")
            valid_mask = ~np.isnan(coords).any(axis=1)
            adata_batch = adata_batch[valid_mask].copy()
    
    
    #try:
    sq.gr.spatial_neighbors(adata_batch,
                                coord_type="generic",
                                spatial_key=spatial_key,
                                n_neighs=n_neighbors)
    #except:
    #    continue
    print(f"Spatial neighbours done ## {adata_batch.shape}")

    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
print("List made: ...")
for x in adata_batch_list:
    print(x.shape)
adata_vis = ad.concat(adata_batch_list, join="inner")
# Out:
# Processing reference batches...
# Processing batch BK50_Past Lesional...
# Loading data...
# Size (9800, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (9800, 5178)
# Processing batch BK49_Past Lesional wk8 relaspe...
# Loading data...
# Size (12682, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12682, 5178)
# Processing batch BK46_Never Lesional...
# Loading data...
# Size (18754, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (18754, 5178)
# Processing batch BK51_Past Lesional wk8 relaspe...
# Loading data...
# Size (10690, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (10690, 5178)
# Processing batch BK51_wk8 Relapse...
# Loading data...
# Size (14433, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14433, 5178)
# Processing batch BK46_Past Lesional...
# Loading data...
# Size (18353, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18353, 5178)
# Processing batch BK43_Past Lesional...
# Loading data...
# Size (6883, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6883, 5178)
# Processing batch BK43_Never Lesional...
# Loading data...
# Size (12110, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (12110, 5178)
# Processing batch BK49_wk8 Relapse...
# Loading data...
# Size (11403, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11403, 5178)
# Processing batch BK49_Past Lesional...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (27387, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (27387, 5178)
# Processing batch BK49_Never Lesional...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (13472, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (13472, 5178)
# Processing batch BK51_Never Lesional...
# Loading data...
# Size (15454, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (15454, 5178)
# Processing batch BK50_Never Lesional...
# Loading data...
# Size (14673, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14673, 5178)
# Processing batch BK51_Past Lesional...
# Loading data...
# Size (12627, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12627, 5178)
# Processing batch BK22_Lesional Baseline...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (21567, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (21567, 5178)
# Processing batch BK23_Week 12...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (11247, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11247, 5178)
# Processing batch BK23_Non-lesional Baseline...
# Loading data...
# Size (17684, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17684, 5178)
# Processing batch BK23_Lesional Baseline...
# Loading data...
# Size (24433, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (24433, 5178)
# Processing batch BK22_Non-lesional Baseline...
# Loading data...
# Size (9152, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9152, 5178)
# Processing batch BK27_Week 12...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (13422, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (13422, 5178)
# Processing batch BK21_Lesional Baseline...
# Loading data...
# Size (15508, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (15508, 5178)
# Processing batch BK20_Lesional Baseline...
# Loading data...
# Size (2290, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (2290, 5178)
# Processing batch BK18_Non-lesional Baseline...
# Loading data...
# Size (7620, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (7620, 5178)
# Processing batch BK18_Week 12...
# Loading data...
# Size (15091, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15091, 5178)
# Processing batch BK27_Non-lesional Baseline...
# Loading data...
# Size (8579, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8579, 5178)
# Processing batch BK27_Lesional Baseline...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (7907, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7907, 5178)
# Processing batch BK18_Lesional Baseline...
# Loading data...
# Size (17731, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17731, 5178)
# Processing batch BK21_Non-lesional Baseline...
# Loading data...
# Size (6127, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6127, 5178)
# Processing batch BK20_Week 12...
# Loading data...
# Size (14893, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14893, 5178)
# Processing batch BK21_Week 12...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (8978, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8978, 5178)
# Processing batch BK20_Non-lesional Baseline...
# Loading data...
# Size (6870, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6870, 5178)
# Processing batch BK39_Lesional Baseline...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (16503, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (16503, 5178)
# Processing batch BK39_Non-lesional Baseline...
# Loading data...
# Size (16377, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (16377, 5178)
# Processing batch BK39_Week 12...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (32058, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (32058, 5178)
# Processing batch BK25_Non-lesional Baseline...
# Loading data...
# Size (13511, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13511, 5178)
# Processing batch BK30_Day 14...
# Loading data...
# Size (30438, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (30438, 5178)
# Processing batch BK25_Lesional Baseline...
# Loading data...
# Size (11638, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (11638, 5178)
# Processing batch BK25_Week 12...
# Loading data...
# Size (13999, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13999, 5178)
# Processing batch BK30_Non-lesional Baseline...
# Loading data...
# Size (16910, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16910, 5178)
# Processing batch BK30_Lesional Baseline...
# Loading data...
# Size (13456, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13456, 5178)
# Processing batch BK30_Week 12...
# Loading data...
# Size (18678, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18678, 5178)
# Processing batch BK24_Week 12...
# Loading data...
# Size (11265, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11265, 5178)
# Processing batch BK24_Non-lesional Baseline...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (12069, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12069, 5178)
# Processing batch BK24_Lesional Baseline...
# Loading data...
# Size (12954, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (12954, 5178)
# Processing batch Baseline_resolved_CE6-SKI-28-FO-1-S22-B2...
# Loading data...
# Size (9387, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9387, 5178)
# Processing batch Lesional_CE5-SKI-28-FO-1-S22-A1...
# Loading data...
# Size (11082, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (11082, 5178)
# Processing batch Baseline_resolved_CE3-SKI-28-FO-1-S22-B1...
# Loading data...
# Size (6193, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6193, 5178)
# Processing batch Baseline_resolved_CE4-SKI-27-FO-1-S22-B2...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (5642, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (5642, 5178)
# Processing batch Lesional_CE6-SKI-28-FO-4-S22-A1...
# Loading data...
# Size (8121, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8121, 5178)
# Processing batch Baseline_never_CE5-SKI-27-FO-2-S22-C1...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (11041, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11041, 5178)
# Processing batch Week 8 (resolved)_CE5-SKI-27-FO-4-S22-E1...
# Loading data...
# Size (18088, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (18088, 5178)
# Processing batch Lesional_CE3-SKI-24-FO-1-S22-A1...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (22124, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (22124, 5178)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Processing batch Week 8 (resolved)_CE4-SKI-27-FO-3-S22-E2_a...
# Loading data...
# Size (11135, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11135, 5178)
# Processing batch Week 8 (resolved)_CE3-SKI-28-FO-4-S22-E1_a...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (12801, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12801, 5178)
# Processing batch Week 8 (resolved)_CE6-SKI-28-FO-3-S22-E2...
# Loading data...
# Size (8452, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (8452, 5178)
# Processing batch Baseline_never_CE4-SKI-21-FO-1-S22-C2...
# Loading data...
# Size (9319, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9319, 5178)
# Processing batch Week 8 (resolved)_CE4-SKI-27-FO-3-S22-E2_b...
# Loading data...
# Size (11694, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11694, 5178)
# Processing batch Week 8 (resolved)_CE3-SKI-28-FO-4-S22-E1_b...
# Loading data...
# Size (9924, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (9924, 5178)
# Processing batch Baseline_resolved_CE5-SKI-27-FO-1-S22-B1...
# Loading data...
# Size (15680, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (15680, 5178)
# Processing batch Baseline_never_CE3-SKI-28-FO-2-S22-C1...
# Loading data...
# Size (14745, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14745, 5178)
# Processing batch Lesional_CE4-SKI-27-FO-4-S22-A2...
# Loading data...
# Size (20471, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20471, 5178)
# Processing batch Baseline_resolved_CE6-SKI-20-FO-1-S22-C2...
# Loading data...
# Size (6046, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6046, 5178)
# Processing batch Week 8 (resolved)_CE6-SKI-28-FO-3-S22_replicate...
# Loading data...
# Size (8357, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (8357, 5178)
# Processing batch Baseline_never_CE5-SKI-27-FO-2-S22_replicate...
# Loading data...
# Size (10700, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10700, 5178)
# Processing batch Baseline_resolved_CE3-SKI-28-FO-1-S22_replicate...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (6214, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6214, 5178)
# Processing batch Baseline_resolved_CE6-SKI-20-FO-1-S22_replicate...
# Loading data...
# Size (5853, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (5853, 5178)
# Processing batch Lesional_CE6-SKI-28-FO-4-S22_replicate...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (7729, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7729, 5178)
# Processing batch Lesional_CE4-SKI-27-FO-4-S22_replicate...
# Loading data...
# Size (20573, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20573, 5178)
# Processing batch Week 8 (resolved)_CE5-SKI-27-FO-4-S22_replicate...
# Loading data...
# Size (17704, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17704, 5178)
# Processing batch Baseline_resolved_CE6-SKI-28-FO-4-S22_replicate...
# Loading data...
# Size (9172, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9172, 5178)
# Processing batch Lesional_CE5-SKI-28-FO-1-S22_replicate...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (10902, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10902, 5178)
# Processing batch Baseline_resolved_CE4-SKI-27-FO-1-S22_replicate...
# Loading data...
# Size (5477, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (5477, 5178)
# Processing batch Week 8 (resolved)_CE3-SKI-28-FO-4-S22_replicate...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (12504, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12504, 5178)
# Processing batch Week 8 (resolved)_CE4-SKI-27-FO-3-S22_replicate...
# Loading data...
# Size (10820, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (10820, 5178)
# Processing batch Lesional_Baseline_resolved_CE3-SKI-24-FO-1-S22_replicate...
# Loading data...
# Size (21443, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (21443, 5178)
# Processing batch Baseline_never_CE3-SKI-28-FO-2-S22_replicate...
# Loading data...
# Size (14257, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14257, 5178)
# Processing batch Baseline_resolved_CE5-SKI-27-FO-1-S22_replicate...
# Loading data...
# Size (15256, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (15256, 5178)
# Processing batch Baseline_never_CE4-SKI-21-FO-1-S22_replicate...
# Loading data...
# Size (9119, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9119, 5178)
# Processing batch Healthy2...
# Loading data...
# Size (29482, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (29482, 5178)
# Processing batch Healthy1...
# Loading data...
# Size (29833, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (29833, 5178)
# Processing batch 3D_BK22_Lesional_baseline-A2...
# Loading data...
# Size (19147, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (19147, 5178)
# Processing batch 3D_BK25_week12-D1orE1a...
# Loading data...
# Size (16887, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16887, 5178)
# Processing batch 3D_BK25_week12-A1...
# Loading data...
# Size (14728, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14728, 5178)
# Processing batch 3D_BK22_Lesional_baseline-D1...
# Loading data...
# Size (23777, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (23777, 5178)
# Processing batch 3D_BK25_week12-D1orE1b...
# Loading data...
# Size (17173, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17173, 5178)
# Processing batch 3D_BK25_week12-B1...
# Loading data...
# Size (16608, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16608, 5178)
# Processing batch 3D_BK22_Lesional_baseline-B2...
# Loading data...
# Size (24315, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (24315, 5178)
# Processing batch 3D_BK25_week12-C1...
# Loading data...
# Size (16095, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16095, 5178)
# Processing batch 3D_BK25_week12-D2...
# Loading data...
# Size (41325, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (41325, 5178)
# Processing batch 3D_BK22_Lesional_baseline-D2...
# Loading data...
# Size (20714, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20714, 5178)
# Processing batch 3D_BK25_week12-B2...
# Loading data...
# Size (17723, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17723, 5178)
# Processing batch 3D_BK22_Lesional_baseline-A1...
# Loading data...
# Size (23013, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (23013, 5178)
# Processing batch 3D_BK25_week12-C2...
# Loading data...
# Size (19688, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (19688, 5178)
# Processing batch 3D_BK25_week12-A2...
# Loading data...
# Size (20084, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20084, 5178)
# Processing batch 3D_BK22_Lesional_baseline-B1...
# Loading data...
# Size (20444, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20444, 5178)
# Processing batch 3D_BK22_Lesional_baseline-C2...
# Loading data...
# Size (22069, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (22069, 5178)
# Processing batch BK22_Week 12...
# Loading data...
# Size (9649, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9649, 5178)
# Processing batch output-XETG00272__0081038__BK74-SKI-26-FO-1-s2__20260413__125221...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (24599, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (24599, 5178)
# Processing batch output-XETG00272__0080896__BK72-SKI-27-FO-1-s3__20260413__125221...
# Loading data...
# Size (16497, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16497, 5178)
# Processing batch output-XETG00272__0080896__BK72-SKI-28-FO-1-s5__20260413__125221...
# Loading data...
# Size (6631, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (6631, 5178)
# Processing batch output-XETG00272__0080896__BK72-SKI-0-FO-1-s5_BK72-SKI-22-FO-1-s5__20260413__125221...
# Loading data...
# Size (27877, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (27877, 5178)
# Processing batch output-XETG00272__0081038__BK74-SKI-27-FO-4-s3__20260413__125221...
# Loading data...
# Size (17601, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17601, 5178)
# Processing batch output-XETG00272__0081038__BK73-SKI-26-FO-1-s2__20260413__125221...
# Loading data...
# Size (14358, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14358, 5178)
# Processing batch output-XETG00272__0080896__BK70-SKI-22-FO-1-s5_BK72-SKI-26-FO-1-s5__20260413__125221...
# Loading data...
# Size (24514, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (24514, 5178)
# Processing batch output-XETG00272__0080896__BK70-SKI-28-FO-1-s5__20260413__125220...
# Loading data...
# Size (13737, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13737, 5178)
# Processing batch output-XETG00272__0080896__BK70-SKI-0-FO-1-s5__20260413__125221...
# Loading data...
# Size (20903, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20903, 5178)
# Processing batch output-XETG00272__0081038__BK73-SKI-26-FO-3-s2_BK74-SKI-27-FO-1-s2__20260413__125221...
# Loading data...
# Size (32171, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (32171, 5178)
# Processing batch output-XETG00272__0080896__BK70-SKI-27-FO-1-s5__20260413__125221...
# Loading data...
# Size (16999, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16999, 5178)
# Processing batch output-XETG00272__0081038__BK73-SKI-27-FO-1-s2__20260413__125221...
# Loading data...
# Size (7602, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (7602, 5178)
# Processing batch output-XETG00272__0081038__BK74-SKI-27-FO-3-s3__20260413__125221...
# Loading data...
# Size (18584, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18584, 5178)
# Processing batch output-XETG00155__0032945__AX34-SKI-0-FO-2-S3-A2__20241217__145711...
# Loading data...
# Size (22607, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (22607, 5178)
# Processing batch output-XETG00272__0021042__AX29-SKI-0-FO-2-S4__20240815__114049...
# Loading data...
# Size (14193, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (14193, 5178)
# Processing batch output-XETG00155__0032957__AX38-SKI-0-FO-1-S3-B1__20241217__145711...
# Loading data...
# Size (33391, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (33391, 5178)
# Processing batch output-XETG00155__0032957__AX37-SKI-0-FO-2-S3-A2__20241217__145711...
# Loading data...
# Size (13306, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (13306, 5178)
# Processing batch output-XETG00155__0032945__AX34-SKI-0-FO-1-S3-A1__20241217__145711...
# Loading data...
# Size (12114, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (12114, 5178)
# Processing batch output-XETG00272__0021042__AX29-SKI-0-FO-1-S4__20240815__114049...
# Loading data...
# Size (36882, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (36882, 5178)
# Processing batch output-XETG00272__0021042__AX30-SKI-0-FO-2-S3__20240815__114049...
# Loading data...
# Size (13416, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# /tmp/ipykernel_2079761/3100873734.py:20: ImplicitModificationWarning: Setting element `.obsm['spatial']` of view, initializing view as actual.
#   adata_batch.obsm[spatial_key] = adata_batch.obs[['x_centroid', 'y_centroid']].values
# Reconstructed coordinates from centroids
# Spatial neighbours done ## (13416, 5178)
# Processing batch output-XETG00272__0021042__AX30-SKI-0-FO-1-S3__20240815__114049...
# Loading data...
# Size (29148, 5178)
# Computing spatial neighborhood graph...
#
# NaN detected in spatial coordinates, reconstructing from centroids...
# ...
#   obj[key] = data
# Spatial neighbours done ## (22649, 5178)
# Processing batch output-XETG00335__0072771__BK27-SKI-27-FO-1-S6-C1__20250826__123231...
# Loading data...
# Size (20808, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20808, 5178)
# Processing batch output-XETG00335__00728669__CE4-SKI-27-FO-1-S25-S29-S32__20250826__123231...
# Loading data...
# Size (26630, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (26630, 5178)
# Processing batch output-XETG00335__00728669__BK51-SKI-27-FO-2-S4-S8-S6__20250826__123231...
# Loading data...
# Size (27213, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (27213, 5178)
# Processing batch output-XETG00335__0072771__BK23-SKI-27-FO-5-S9-A2__20250826__123231...
# Loading data...
# Size (23070, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (23070, 5178)
# Processing batch BK43_wk4 Relapse...
# Loading data...
# Size (14035, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14035, 5178)
# Processing batch BK46_wk4 Relapse...
# Loading data...
# Size (13244, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13244, 5178)
# Processing batch BK51_Past Lesional wk4 Relapse...
# Loading data...
# Size (12503, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (12503, 5178)
# Processing batch BK49_Past Lesional wk4 Relapse...
# Loading data...
# Size (19969, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (19969, 5178)
# Processing batch BK50_wk4 Relapse...
# Loading data...
# Size (24857, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (24857, 5178)
# Processing batch BK23_Day 14...
# Loading data...
# Size (7691, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7691, 5178)
# Processing batch BK22_Day 14...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (9007, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9007, 5178)
# Processing batch BK22_Day 3...
# Loading data...
# Size (11214, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (11214, 5178)
# Processing batch BK23_Day 3...
# Loading data...
# Size (8160, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8160, 5178)
# Processing batch BK27_Day 14...
# Loading data...
# Size (8420, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8420, 5178)
# Processing batch BK21_Day 3...
# Loading data...
# Size (8944, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (8944, 5178)
# Processing batch BK20_Day 14...
# Loading data...
# Size (5628, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (5628, 5178)
# Processing batch BK21_Day 14...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (10438, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10438, 5178)
# Processing batch BK18_Day 3...
# Loading data...
# Size (14274, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14274, 5178)
# Processing batch BK27_Day 3...
# Loading data...
# Size (14554, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14554, 5178)
# Processing batch BK20_Day 3...
# Loading data...
# Size (17989, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17989, 5178)
# Processing batch BK18_Day 14...
# Loading data...
# Size (13434, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13434, 5178)
# Processing batch BK25_Day 3...
# Loading data...
# Size (9493, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9493, 5178)
# Processing batch BK25_Day 14...
# Loading data...
# Size (3038, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (3038, 5178)
# Processing batch BK30_Day 3...
# Loading data...
# Size (7345, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (7345, 5178)
# Processing batch BK24_Day 14...
# Loading data...
# Size (9843, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9843, 5178)
# Processing batch BK39_Day 14...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (10775, 5178)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10775, 5178)
# Processing batch BK24_Day 3...
# Loading data...
# Size (10146, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (10146, 5178)
# Processing batch BK39_Day 3...
# Loading data...
# Size (8475, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (8475, 5178)
# Processing batch Week 4 (resolved)_CE6-SKI-28-FO-2-S22-D2...
# Loading data...
# Size (11658, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (11658, 5178)
# Processing batch Week 4 (resolved)_CE5-SKI-27-FO-3-S22-D1...
# Loading data...
# Size (19360, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (19360, 5178)
# Processing batch output-XETG00495__0068445__13871-JF-1_ROI-7__20250821__165859...
# Loading data...
# Size (40024, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (40024, 5178)
# Processing batch output-XETG00495__0068445__13871-JF-1_ROI-2__20250821__165859...
# Loading data...
# Size (25690, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (25690, 5178)
# Processing batch output-XETG00495__0068445__13871-JF-1_ROI-8__20250821__165859...
# Loading data...
# Size (26199, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (26199, 5178)
# Processing batch output-XETG00495__0068445__13871-JF-1_ROI-1__20250821__165858...
# Loading data...
# Size (18037, 5178)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18037, 5178)
# List made: ...
# (9800, 5178)
# (12682, 5178)
# (18754, 5178)
# (10690, 5178)
# (14433, 5178)
# (18353, 5178)
# (6883, 5178)
# (12110, 5178)
# (11403, 5178)
# (27387, 5178)
# (13472, 5178)
# (15454, 5178)
# (14673, 5178)
# (12627, 5178)
# (21567, 5178)
# (11247, 5178)
# (17684, 5178)
# (24433, 5178)
# (9152, 5178)
# (13422, 5178)
# (15508, 5178)
# (2290, 5178)
# (7620, 5178)
# (15091, 5178)
# (8579, 5178)
# (7907, 5178)
# (17731, 5178)
# (6127, 5178)
# (14893, 5178)
# (8978, 5178)
# (6870, 5178)
# (16503, 5178)
# (16377, 5178)
# (32058, 5178)
# (13511, 5178)
# (30438, 5178)
# (11638, 5178)
# (13999, 5178)
# (16910, 5178)
# (13456, 5178)
# (18678, 5178)
# (11265, 5178)
# (12069, 5178)
# (12954, 5178)
# (9387, 5178)
# (11082, 5178)
# (6193, 5178)
# (5642, 5178)
# (8121, 5178)
# (11041, 5178)
# (18088, 5178)
# (22124, 5178)
# (11135, 5178)
# (12801, 5178)
# (8452, 5178)
# (9319, 5178)
# (11694, 5178)
# (9924, 5178)
# (15680, 5178)
# (14745, 5178)
# (20471, 5178)
# (6046, 5178)
# (8357, 5178)
# (10700, 5178)
# (6214, 5178)
# (5853, 5178)
# (7729, 5178)
# (20573, 5178)
# (17704, 5178)
# (9172, 5178)
# (10902, 5178)
# (5477, 5178)
# (12504, 5178)
# (10820, 5178)
# (21443, 5178)
# (14257, 5178)
# (15256, 5178)
# (9119, 5178)
# (29482, 5178)
# (29833, 5178)
# (19147, 5178)
# (16887, 5178)
# (14728, 5178)
# (23777, 5178)
# (17173, 5178)
# (16608, 5178)
# (24315, 5178)
# (16095, 5178)
# (41325, 5178)
# (20714, 5178)
# (17723, 5178)
# (23013, 5178)
# (19688, 5178)
# (20084, 5178)
# (20444, 5178)
# (22069, 5178)
# (9649, 5178)
# (24599, 5178)
# (16497, 5178)
# (6631, 5178)
# (27877, 5178)
# (17601, 5178)
# (14358, 5178)
# (24514, 5178)
# (13737, 5178)
# (20903, 5178)
# (32171, 5178)
# (16999, 5178)
# (7602, 5178)
# (18584, 5178)
# (22607, 5178)
# (14193, 5178)
# (33391, 5178)
# (13306, 5178)
# (12114, 5178)
# (36882, 5178)
# (13416, 5178)
# (29148, 5178)
# (98602, 5178)
# (24602, 5178)
# (13190, 5178)
# (14011, 5178)
# (19762, 5178)
# (18809, 5178)
# (29527, 5178)
# (30151, 5178)
# (19285, 5178)
# (14787, 5178)
# (19273, 5178)
# (9653, 5178)
# (21005, 5178)
# (20510, 5178)
# (16882, 5178)
# (16150, 5178)
# (15671, 5178)
# (12674, 5178)
# (15892, 5178)
# (26549, 5178)
# (19000, 5178)
# (16359, 5178)
# (22488, 5178)
# (8068, 5178)
# (20644, 5178)
# (16626, 5178)
# (15715, 5178)
# (19416, 5178)
# (9713, 5178)
# (22649, 5178)
# (20808, 5178)
# (26630, 5178)
# (27213, 5178)
# (23070, 5178)
# (14035, 5178)
# (13244, 5178)
# (12503, 5178)
# (19969, 5178)
# (24857, 5178)
# (7691, 5178)
# (9007, 5178)
# (11214, 5178)
# (8160, 5178)
# (8420, 5178)
# (8944, 5178)
# (5628, 5178)
# (10438, 5178)
# (14274, 5178)
# (14554, 5178)
# (17989, 5178)
# (13434, 5178)
# (9493, 5178)
# (3038, 5178)
# (7345, 5178)
# (9843, 5178)
# (10775, 5178)
# (10146, 5178)
# (8475, 5178)
# (11658, 5178)
# (19360, 5178)
# (40024, 5178)
# (25690, 5178)
# (26199, 5178)
# (18037, 5178)

# %%
# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_vis.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_vis.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_vis.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_vis.obsp[adj_key] = sp.vstack(batch_connectivities)

# %%
sq.gr.spatial_autocorr(adata_vis, mode="moran", genes=adata_vis.var_names)
# Out:
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/scanpy/metrics/_gearys_c.py:295: UserWarning: 77 variables were constant, will return nan for these.
#   warnings.warn(

# %%
sv_genes = adata_vis.uns["moranI"].index[:n_svg].tolist()

# %%
adata_vis.var["spatially_variable"] = adata_vis.var_names.isin(sv_genes)
adata_vis.var["keep_gene"] = adata_vis.var["spatially_variable"]
adata_vis = adata_vis[:, adata_vis.var["keep_gene"] == True]
print(f"Keeping {len(adata_vis.var_names)} spatially variable, highly "
       "variable or gene program relevant genes.")
# Out:
# Keeping 2048 spatially variable, highly variable or gene program relevant genes.

# %%
import pickle
filepath = f"{handle}/svgenelist.pkl"
with open(filepath, "wb") as f:
    pickle.dump(sv_genes, f)

# %%
# sv_genes

# %%
adata_vis
# Out:
# View of AnnData object with n_obs × n_vars = 2985413 × 2048
#     obs: 'sample_id', 'barcode', 'GSE', 'Site_status', 'Patient_status', 'Location', 'Age', 'Sex', 'dataset_id', 'lvl5_annotation', 'atlas_status', 'atlas_status_reynolds', 'Timepoint', 'info_id6', 'tech', 'scanvi_predictions2', 'lvl1_new', 'Site_status_binary2', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id_dir', 'patient_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'Mapping_status', 'scanvi_predictions', 'broad_annotation', 'fine_annotations', 'fine_annotation', 'disease', 'tmp', 'broad_celltypes', 'tech2', 'time_direction', 'fine_celltypes', 'region', 'celltype', 'DonorID', 'niche_name', 'info_id', 'leiden_res1', 'leiden_res2', 'original_celltypes', 'n_genes', 'NICHE_NAMES', 'leiden_res0.5', 'spatial_niche', 'sample_id2', 'xenium_id', 'xenium_id_recoded', 'sample_id_original', 'timepoint', 'drug', 'responder', 'new_annotation', '6m_easi', 'baseline_easi', 'response', 'Sanger patient ID', 'GSTT patient ID', 'Drug', 'Responder', "Library type (CITE or 5'GEX/TCR)", 'Segmentation Y/N?', 'Sample ID', 'Xenium slide number', 'Xenium region number2', 'baseline_postrx', 'Annotation', 'batch', 'new_annotation2', 'new_annotation3', 'annotation_new4', 'new_annotation4', 'new_annotation5', 'new_annotation6', 'sample', 'veryfine_celltypes_new', 'niche_category', 'veryfine_celltypes_new2', 'lvl1', 'lvl0', 'veryfine_celltypes_new3', 'veryfine_celltypes_new4', 'test', 'veryfine_celltypes_new5', 'veryfine_celltypes_new5_incprolif', 'veryfine_celltypes', 'fine_celltypes_new', 'mod_celltypes_new', 'broad_celltypes_new', 'Site_status_binary', 'lvl4_annotation', 'number', 'lvl3_annotation', 'disease_overall', 'lvl0_annotation', 'lvl0_annotation2', 'lvl1_annotation', 'lvl1_annotation2', 'lvl1_annotation3', 'lvl1_annotation4', 'lvl1_annotation5', 'lvl1_annotation6', 'lvl1_annotation7', 'lvl1_annotation8', 'lvl2_annotation9', 'Annotation_tomap', 'leiden_res3', 'lvl3_annotation3', 'lvl3_annotation4', 'lvl3_annotation5', 'combined_annotation', 'combined_annotation2', 'lvl5_annotation_new3', 'lvl0_new', 'combined_annotation3', 'combined_annotation4', 'combined_annotation6', 'combined_annotation7', 'combined_annotation8', 'combined_annotation9', 'final_annotation', 'final_annotation2', 'final_annotation3', 'final_annotation4', 'final_annotation5', 'final_annotation7', 'final_annotation8', 'final_annotation9', 'final_annotation10', 'final_annotation_lvl5temp', 'niche_names', 'niche10', 'info_id2', 'final_annotation_lvl4', 'final_annotation_lvl3', 'niche11', 'final_annotation5_3', 'final_annotation5_2', 'final_annotation_lvl5_4', 'FinalXeniumScanVI_14', 'leiden_res0.1', 'FinalXeniumScanVI_16', 'FinalXeniumScanVI_17', 'niche12', 'lvl2_annotation', 'Timepoint2', 'Site_status_simple', 'updatenames1', 'updatenames2', 'updatenames3', 'lvl5_annotation_new', 'lvl5_annotation_new2', 'lvl5_annotation_new4', 'lvl5_annotation_new5', 'lvl5_annotation_new_preophan', 'lvl5_annotation_new9', 'lvl5_annotation_new12', 'lvl5_annotation_new13', 'baseline_severity', 'temp', 'lvl4_annotation_sept', 'prep', 'Site_status_archive', 'response_binned', 'xenium_id_recoded2', 'RUN_ID', 'newintegration', 'leiden_res0.2', 'replicate_id', 'fig8_mapping', 'all_vs_core', 'sample_id_nemo', 'leiden_res4', 'niche14', 'provisional', 'provisional2', 'atlas_status_simple', 'niche19', 'data_addition', 'fig1a_numbers_scrna', 'fig1_numbers_xenium_without_validation_data', 'Site_status2', 'info_id6_recode', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'QC_hi', 'QC_mid', 'l ...
#     var: 'spatially_variable', 'keep_gene'
#     uns: 'moranI'
#     obsm: 'X_scanvi', 'X_scvi', 'X_umap', 'cell_emb', 'neighborhood_emb', 'spatial'
#     layers: 'X_count', 'X_rank', 'counts'
#     obsp: 'spatial_connectivities'

# %%
for x in adata_vis.obs.columns:
    adata_vis.obs[x]=    adata_vis.obs[x].astype(str)
# Out:
# /tmp/ipykernel_2079761/3822545579.py:2: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_vis.obs[x]=    adata_vis.obs[x].astype(str)

# %%
# for x in adata.var.columns:
#     adata.var[x]=    adata.var[x].astype(str)

# %%
ADATA_PATH= '/lustre/scratch124/cellgen/haniffa/projects/adult_skin_v1/nobackup_data/adata_all_fornc.h5ad'

# %%
ADATA_PATH + ".svg"
# Out:
# '/lustre/scratch124/cellgen/haniffa/projects/adult_skin_v1/nobackup_data/adata_all_fornc.h5ad.svg'

# %%
adata_vis.obsm
# Out:
# AxisArrays with keys: X_scanvi, X_scvi, X_umap, cell_emb, neighborhood_emb, spatial

# %%
for x in adata_vis.obs.columns:
    adata_vis.obs[x]=adata_vis.obs[x].astype(str)

# %%
adata_vis.obsm["spatial"]#.fillna().sum()

# %%
# If spatial coordinates are broken, rebuild from centroids
if 'x_centroid' in adata_vis.obs and 'y_centroid' in adata_vis.obs:
    adata_vis.obsm["spatial"] = adata_vis.obs[['x_centroid', 'y_centroid']].values.astype(np.float32)
    print("Rebuilt spatial coordinates from centroids")

# %%
for x in adata_vis.obs.columns:
    adata_vis.obs[x]=adata_vis.obs[x].astype(str)

# %%
adata_vis.write(ADATA_PATH + ".svg")  
print(ADATA_PATH + ".svg")
# Out:
# /lustre/scratch124/cellgen/haniffa/projects/adult_skin_v1/nobackup_data/adata_all_fornc.h5ad.svg

# %%
1
# Out:
# 1

# %%
# import scanpy as sc
# adata = sc.read_h5ad('/lustre/scratch124/cellgen/haniffa/projects/adult_skin_v1/nobackup_data/adata_core_plus_time_fornc_refquery2.h5ad.svg')

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
# adata=sc.read_h5ad('/lustre/scratch124/cellgen/haniffa/projects/adult_skin_v1/nobackup_data/adata_all_fornc.h5ad.svg')
# adata.shape

# %%
1

# %%
0

# %% [markdown]
# # Split into ref + query adatas

# %%
# ADATA_PATH= '/lustre/scratch126/cellgen/lotfollahi/ls34/nemo/adata_all.h5ad.clustered.clustered10.good.prenichecompass.svg'
# adata_vis=sc.read_h5ad(ADATA_PATH)  
# adata_vis.shape

# %%
query_batches = list(adata_vis[adata_vis.obs["batch_nc"]=="query"].obs["sample"].unique())
reference_batches = list(adata_vis[adata_vis.obs["batch_nc"]=="reference"].obs["sample"].unique())

# %%
adata_vis.obs["batch_nc"].value_counts()

# %%
adata_batch_list = []
print("Processing reference batches...")
for batch in reference_batches:
    print(f"Processing batch {batch}...")
    adata_batch = select_slide2(adata_vis, batch)
    sq.gr.spatial_neighbors(adata_batch,
                                coord_type="generic",
                                spatial_key=spatial_key,
                                n_neighs=n_neighbors)
    #except:
    #    continue
    print(f"Spatial neighbours done ## {adata_batch.shape}")

    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
print("List made: ...")
for x in adata_batch_list:
    print(x.shape)
adata_reference = ad.concat(adata_batch_list, join="inner")

# %%
print("List made: ...", len(adata_batch_list))
for x in adata_batch_list:
    print(x.shape)

# %%
# adata_reference = ad.concat(adata_batch_list, join="inner")

# %%
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_reference.obsp[adj_key] = sp.vstack(batch_connectivities)

# %%
mapping_entity_key = "mapping_entity"
adata_reference.obs[mapping_entity_key] = "reference"

# %%
adata_reference.write(ADATA_PATH + ".svg.reference")  
print(ADATA_PATH + ".svg.reference")

# %%
adata_vis.obs.batch_nc.value_counts()

# %%
query_batches

# %%
adata_batch_list = []
print("Processing query batches...")
# for batch in query_batches:
#     print(f"Processing batch {batch}...")
#     print("Loading data...")
#     adata_batch = sc.read_h5ad(
#         f"{so_data_folder_path}/{dataset}_{batch}.h5ad")
for batch in query_batches:
   # print(f"Processing batch {batch}...")
    #print("Loading data...")
    adata_batch = select_slide2(adata_vis, batch)
    #print("Computing spatial neighborhood graph...\n")
    # Compute (separate) spatial neighborhood graphs
    sq.gr.spatial_neighbors(adata_batch,
                            coord_type="generic",
                            spatial_key=spatial_key,
                            n_neighs=n_neighbors)
    
    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
adata_query = ad.concat(adata_batch_list, join="inner")

# %%
adata_query.obs["sample"].value_counts()

# %%
len(adata_batch_list)

# %%
# adata_batch_list

# %%
for i in range(len(adata_batch_list)):
    print(adata_batch_list[i].shape)

# %%
# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_query.obsp[adj_key] = sp.vstack(batch_connectivities)

adata_query.obs[mapping_entity_key] = "query"

# %%
batch_connectivities = []
len_before_batch = 0

adata_query.obs[mapping_entity_key] = "query"

# %%
adata_query.write(ADATA_PATH + ".svg.query")  
print(ADATA_PATH + ".svg.query")

# %%
"""
this adata can now be used as input for the ref-query tutorial for
nichecompass
https://nichecompass.readthedocs.io/en/latest/tutorials/notebooks/mouse_cns_spatial_reference_mapping.html

we apply this in a python job in ../job_scripts/nichecompass_ref_mapping2.py

"""

# %%
.

# %% [markdown]
# # Results

# %%
PATH_RES = '/lustre/scratch124/cellgen/haniffa/projects/developmental_fibroblasts/nobackup_output/nichecompasss/nichecompass/artifacts/spatial_reference_mapping/20251201_091037XeniumTUTORIAL__REFQ/model/'

# %%
import os
os.listdir(PATH_RES + "reference")

# %%
PATH_RES + "reference"

# %%
import scanpy as sc
adata=sc.read_h5ad ( PATH_RES + "reference_query/adata.h5ad")
adata.obs["batch_nc"].value_counts()

# %%
# import pickle

# outpath = "/nfs/team298/ls34/skin_niche19.pkl"

# with open(outpath, "rb") as f:
#     md_loaded = pickle.load(f)

# adata.obs["niche19"] = adata.obs.index.map(md_loaded)
# adata.obs["niche19"]=adata.obs["niche19"].fillna("QUERY_DATA")

# %%
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(20,20))

sc.pl.umap(
    adata,
    color=[
        "batch_nc",
    ],
    #legend_loc="on data",
    s=10,
    legend_fontsize=54,
    legend_fontoutline=2,
    show=False,
    #palette=colorsmap,
    edgecolor='black',
    linewidth=0.01,
    title='',
    palette=['lightblue', 'orange']
#   save=f"{x}_PAGA.pdf"
)

# %%
colors_new2 = {
        'Epidermis_basal': "#4a538f",# "#3489f1", #"#000080", #"#f0f8ff", #"#007cfe",#'#4f59a1',  # dark blue
    "Epidermis basal":"#3489f1",# "#000080", #"#f0f8ff", #"#000080",
    
                'Epidermis_mid': '#F0F8FF', # #e3e7eb - GREY
  #  "Epidermis_late": "#4682B4", #"#A52A2A",          # pink
            'Epidermis_late':"#2a2f5c",#"#2a2f5c" ,# "#2e2e2e",#'#b1dae6',  # light blue

   'Epidermis basal_cycling': "#007cfe",  #  e2d8dd   "#505aa1",#"#c590a5" , # '#e0c5d2',
'Epidermis_basal_cycling': "#007cfe", 
'EpidermisInflamm_mid':"#f6e3ec",
        'EpidermisInflamm_late': "#800020",
    
    
    # 'Epidermis_Inflammatory': '#f2e7ed',
        "Epidermis_APChi": "#ff1493",
    'Papillary_dermis':"#FFFF00", # "#f6d17a", # yellow
    
  #  'Perivascular':  "#845DAE", #  '#fedbe7' PINKSIH,  #'#f8daeb',  # darkish red
    'Small blood vessel': "#d73435", #'#fe78bb',  # bright red
    'Sweat_gland': '#008080',  # dark grey
        'Sweat_gland_channel': "#adf7e8", #'#008080',  # original - 40E0D0
    'Muscle': "#f371af",  # very dark red
    'Adipocyte+vessels': "#B8860B", #'#FF4500',  # very dark orange
     'Hypodermis': "#FFFFF0", #"#D2B48C",#' # yello  # white = '#ffffff',
    'Larger blood vessel': "#660000",#"#8B0000", #'#FF6347',  # coral red
    'Perineural': '#0A0A0A',  # almost black
   # 'Plasma+pDC': '#808080',  # bright turquoise
    #'Sweat gland channel': '#000000',  # black
    #'KC_immunecell': '#FF1493',  # dark pink
    
   # 'Epidermis_late': '#b1dae6',
    "Nonspecific":"#D3D3D3",
     'Reticular_dermis': '#d0e1f2',

 'Large_BV': '#660000',
 'Small_BV': "#c43f40",#'#D96B6B',
     'Tzone-like': "#845DAE",# '#F4D1A1',

 'Sebaceous_gland': "#FFD9A3",      #  "#FFB347",#"#94cb72",#'#e28743',
"Sebaceous_immune": "#ff6145", 
 #'Plasma_cell_niche': "#1F51FF", #"#FFB300",#"#40E0D0",#'#ff5e00',
   # 'Plasma_cell_rich':  "#8080B2", #"
"Plasma_cell_rich": "#04D9FF",
    'HF_Perineural': '#00FF00',
    "OuterHF": "#006600",# 
 'Sebaceous duct': '#e28743',


"Lymphoid Tzone-like": "#825bac",
    



     #007FFF
    "Reticular_dermis_LE_rich" : "#6A8ED8",
        "Reticular_dermis_LErich" : "#6A8ED8",
    "Small_BV_Trich": "#FFB6C1",          # neon orange
    "Tzone-like_Theavy": "#B19CD9",       # light purple
    #"Reticular dermis_F2/F3hi": "#35476C", #"#FF5F1F",# light blue
    "HF_outer": "#90c670",                # very dark green
    "VenuleMuscle": "#B34A7E",

    "Sebaceous_duct": "#FFA07A",          # light orange (salmony)
    "VenuleEndothelium": "#8B0000",       # dark red
    "HF_inner": "#90EE90",                 # light green
    "HF_TNN+COCH+hi": "#39FF14",          # neon green
    # "Peri_sweat_gland": "#d9f9f7",
    'HF_innermost':  "#D95D54",
  #  'Sebaceous_inner_immune':"#F6A85C",
    'Nonspecific/folded': "#F0F0F0",
 'nan': '#FAFAFA',
    "QUERY_DATA": '#F0F0F0'
    }

# %%
"""
how do niches compare to what we had before
"""
sc.pl.umap(
    adata,
    color=[
        "niche19",
    ],
    legend_loc="on data",
    s=5,
    legend_fontsize=14,
    legend_fontoutline=2,
    show=False,
    #palette=colorsmap,
    edgecolor='black',
    linewidth=0.01,
    title='',
    palette=colors_new2,
#   save=f"{x}_PAGA.pdf"
)

# %%
"""
how do niches compare to what we had before
"""
sc.pl.umap(
    adata,
    color=[
        "niche19",
    ],
   # legend_loc="on data",
    s=5,
    legend_fontsize=14,
    legend_fontoutline=2,
    show=False,
    #palette=colorsmap,
    edgecolor='black',
    linewidth=0.01,
    title='',
    palette=colors_new2,
#   save=f"{x}_PAGA.pdf"
)

# %%
# adata.write( PATH_RES + "reference_query/adata.h5ad")
