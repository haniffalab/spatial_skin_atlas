# %%
"""
A full tutorial is available here:
https://nichecompass.readthedocs.io/en/latest/tutorials/notebooks/mouse_cns_spatial_reference_mapping.html

Here we illustrate preaparation of our core dataset as a reference for mapping the validation data
"""
# Out:
# '\nA full tutorial is available here:\nhttps://nichecompass.readthedocs.io/en/latest/tutorials/notebooks/mouse_cns_spatial_reference_mapping.html\n\nHere we illustrate preaparation of our core dataset as a reference for mapping the validation data\n'

# %%
import os, sys
import random
import warnings
import logging
from datetime import datetime
# import gdown
import anndata as ad
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scipy.sparse as sp
import seaborn as sns
import squidpy as sq
#from matplotlib import gridspec
#from sklearn.preprocessing import MinMaxScaler
from re import sub
import numpy as np
import pickle

# from nichecompass.models import NicheCompass
# from nichecompass.utils import (add_gps_from_gp_dict_to_adata,
#                                 create_new_color_dict,
#                                 compute_communication_gp_network,
#                                 visualize_communication_gp_network,
#                                 extract_gp_dict_from_mebocost_ms_interactions,
#                                 #extract_gp_dict_from_mebocost_es_interactions,
#                                 extract_gp_dict_from_nichenet_lrt_interactions,
#                                 extract_gp_dict_from_omnipath_lr_interactions,
#                                 #filter_and_combine_gp_dict_gps,
#                                 filter_and_combine_gp_dict_gps_v2,
#                                 generate_enriched_gp_info_plots)


# %%
# Out:
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/numba/core/decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/anndata/utils.py:429: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Set output dir + where to find niche compass files

# %%
"""
make sure inside this path, you have the folders gene_annotations 
and gene_programs with the files
(available from https://github.com/Lotfollahi-lab/nichecompass/tree/main/data)
"""

handle='/lustre/scratch124/cellgen/haniffa/projects/developmental_fibroblasts/nobackup_output/nichecompasss/nichecompass/'

# %% [markdown]
# # Choose number of SVGs to reduce dataset to

# %%
n_svg=1024

# %% [markdown]
# # Set up reference and query (important part)

# %%
adata_reference_path='/nfs/team298/ls34/xenium_atlas/model_ALL_CLEAN_scanvi_ALL/adata_counts_integrated_final_colored.h5ad'
adata_ref = sc.read_h5ad(adata_reference_path)

# %%
"""
load adata (includes reference and query)
- note that sample id is in adata.obs["Sample"]
- cell type is in adata.obs["Annotation"]

if using our adata as reference, then either:
1. remove all query samples (in query_batches below), or
2. add query samples to reference_batches, 

and then add your sample id's to query_batches
"""

#'/nfs/team298/ls34/xenium_atlas/model_ALL_CLEAN_scanvi_ALL/adata_counts_integrated_final_colored.h5ad'


ADATA_PATH = '/lustre/scratch124/cellgen/haniffa/projects/beacon/nobackup_data/adata_mintflownonresponse.h5ad.labelled'
def remove_markers(LIST):
    try: 
        LIST = {key: [gene for gene in genes if gene in adata_5k.var_names] 
                           for key, genes in LIST.items()}
    except: 
        LIST =[gene for gene in LIST if gene in adata_5k.var_names]
    return LIST


adata_vis=sc.read_h5ad(ADATA_PATH)

# %%
adata_vis.layers["counts"] = adata_vis.X.copy()

# %%
adata_vis.shape
# Out:
# (203397, 5001)

# %%
adata_vis.obs["info_id6"].value_counts()
# Out:
# info_id6
# BK44-SKI-27-FO-1-S4-E2    30151
# BK40-SKI-27-FO-1-S4-D2    29527
# BK68-SKI-27-FO-1-S4-B2    24602
# BK65-SKI-21-FO-1-S4-B1    19762
# BK36-SKI-27-FO-1-S4-D1    19285
# BK42-SKI-27-FO-1-S4-C2    19273
# BK36-SKI-27-FO-1-S5-E1    18809
# BK37-SKI-27-FO-1-S4-C1    14787
# BK58-SKI-27-FO-1-S5-A1    14011
# BK58-SKI-27-FO-4-S4-A2    13190
# Name: count, dtype: int64

# %%
adata_vis.obs["sample"]=adata_vis.obs["info_id6"]
adata_vis.obs["sample"].value_counts()
# Out:
# sample
# BK44-SKI-27-FO-1-S4-E2    30151
# BK40-SKI-27-FO-1-S4-D2    29527
# BK68-SKI-27-FO-1-S4-B2    24602
# BK65-SKI-21-FO-1-S4-B1    19762
# BK36-SKI-27-FO-1-S4-D1    19285
# BK42-SKI-27-FO-1-S4-C2    19273
# BK36-SKI-27-FO-1-S5-E1    18809
# BK37-SKI-27-FO-1-S4-C1    14787
# BK58-SKI-27-FO-1-S5-A1    14011
# BK58-SKI-27-FO-4-S4-A2    13190
# Name: count, dtype: int64

# %%
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 203397 × 5001
#     obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'Patient_status', 'xenium_id', 'xenium_id_recoded', 'info_id6', 'sample_id_original', 'sample_id2', 'timepoint', 'drug', 'responder', 'new_annotation', '6m_easi', 'baseline_easi', 'response', 'sample'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     obsm: 'spatial'

# %%
adata_vis.obs["Annotation"]=adata_vis.obs["new_annotation"]

# %%
# adata_vis.obs["Annotation"].value_counts()

# %%
adata_vis.obs["sample"].unique().to_list()
# Out:
# /tmp/ipykernel_214891/3695155828.py:1: FutureWarning: Categorical.to_list is deprecated and will be removed in a future version. Use obj.tolist() instead
#   adata_vis.obs["info_id6"].unique().to_list()
# ['BK68-SKI-27-FO-1-S4-B2',
#  'BK58-SKI-27-FO-4-S4-A2',
#  'BK58-SKI-27-FO-1-S5-A1',
#  'BK65-SKI-21-FO-1-S4-B1',
#  'BK36-SKI-27-FO-1-S5-E1',
#  'BK40-SKI-27-FO-1-S4-D2',
#  'BK44-SKI-27-FO-1-S4-E2',
#  'BK36-SKI-27-FO-1-S4-D1',
#  'BK37-SKI-27-FO-1-S4-C1',
#  'BK42-SKI-27-FO-1-S4-C2']

# %%
adata_vis = ad.concat([adata_vis, adata_ref], 
                     label="batch_nc",
                      keys=["query", "reference"]
                
                     )

# %%
"""
SPLIT INTO REFERENCE AND QUERY
"""
 
"""
replace these query batches with your samples
"""
query_batches = ['BK68-SKI-27-FO-1-S4-B2',
 'BK58-SKI-27-FO-4-S4-A2',
 'BK58-SKI-27-FO-1-S5-A1',
 'BK65-SKI-21-FO-1-S4-B1',
 'BK36-SKI-27-FO-1-S5-E1',
 'BK40-SKI-27-FO-1-S4-D2',
 'BK44-SKI-27-FO-1-S4-E2',
 'BK36-SKI-27-FO-1-S4-D1',
 'BK37-SKI-27-FO-1-S4-C1',
 'BK42-SKI-27-FO-1-S4-C2']

reference_batches = [x for x in adata_vis.obs["sample"].unique() if x not in query_batches]
reference_batches
# Out:
# ['BK59_UNKNOWN_FFPE',
#  'BK58_UNKNOWN_FFPE',
#  'BK57_UNKNOWN_FFPE',
#  'BK50_Past Lesional',
#  'BK56_UNKNOWN_FFPE',
#  'BK49_Past Lesional wk8 relaspe',
#  'BK43_wk4 Relapse',
#  'BK46_wk4 Relapse',
#  'BK46_Never Lesional',
#  'BK51_Past Lesional wk8 relaspe',
#  'BK51_Past Lesional wk4 Relapse',
#  'BK51_wk8 Relapse',
#  'BK46_Past Lesional',
#  'BK43_Past Lesional',
#  'BK43_Never Lesional',
#  'BK49_Past Lesional wk4 Relapse',
#  'BK49_wk8 Relapse',
#  'BK49_Past Lesional',
#  'BK49_Never Lesional',
#  'BK51_Never Lesional',
#  'BK50_Never Lesional',
#  'BK51_Past Lesional',
#  'BK50_wk4 Relapse',
#  'BK22_Week 12',
#  'BK22_Lesional Baseline',
#  'BK23_Week 12',
#  'BK23_Non-lesional Baseline',
#  'BK23_Day 14',
#  'BK23_Lesional Baseline',
#  'BK22_Day 14',
#  'BK22_Non-lesional Baseline',
#  'BK22_Day 3',
#  'BK23_Day 3',
#  'BK27_Week 12',
#  'BK27_Day 14',
#  'BK21_Lesional Baseline',
#  'BK20_Lesional Baseline',
#  'BK18_Non-lesional Baseline',
#  'BK21_Day 3',
#  'BK18_Week 12',
#  'BK20_Day 14',
#  'BK27_Non-lesional Baseline',
#  'BK27_Lesional Baseline',
#  'BK21_Day 14',
#  'BK18_Lesional Baseline',
#  'BK18_Day 3',
#  'BK27_Day 3',
#  'BK21_Non-lesional Baseline',
#  'BK20_Week 12',
#  'BK21_Week 12',
#  'BK20_Day 3',
#  'BK20_Non-lesional Baseline',
#  'BK18_Day 14',
#  'BK39_Lesional Baseline',
#  'BK39_Non-lesional Baseline',
#  'BK39_Week 12',
#  'BK25_Day 3',
#  'BK25_Day 14',
#  'BK25_Non-lesional Baseline',
#  'BK30_Day 3',
#  'BK30_Day 14',
#  'BK25_Lesional Baseline',
#  'BK25_Week 12',
#  'BK24_Day 14',
#  'BK30_Non-lesional Baseline',
#  'BK30_Lesional Baseline',
#  'BK39_Day 14',
#  'BK24_Day 3',
#  'BK30_Week 12',
#  'BK24_Week 12',
#  'BK39_Day 3',
#  'BK24_Non-lesional Baseline',
#  'BK24_Lesional Baseline',
#  'psoriasis']

# %%
# adata_vis.obs["batch_nc"] = "query"
# adata_vis.obs.loc[adata_vis.obs["sample"].isin(reference_batches), "batch_nc"] = "reference"

# %%
query_check = list(adata_vis[adata_vis.obs["batch_nc"]=="query"].obs["sample"].unique())
for x in query_batches:
    if x not in query_check:
        raise ValueError(f"Batch '{x}' not found in query samples.")

# %%
all_batches = reference_batches +query_batches

# %%
### from jimmy lee 
def select_slide2(adata, s, s_col='sample'):
    """ This function selects the data for one slide from the spatial anndata object.
    :param adata: Anndata object with multiple spatial experiments
    :param s: name of selected experiment
    :param s_col: column in adata.obs listing experiment name for each location
    """
    slide = adata[adata.obs[s_col].isin([s]), :]
#     s_keys = list(slide.uns['spatial'].keys())
#     s_spatial = np.array(s_keys)[[s in k for k in s_keys]][0]
#     slide.uns['spatial'] = {s_spatial: slide.uns['spatial'][s_spatial]}
    return slide

# %%
spatial_key = "spatial"
n_neighbors = 8
adj_key = "spatial_connectivities"

adata_batch_list = []
print("Processing reference batches...")
for batch in all_batches:
    print(f"Processing batch {batch}...")
    print("Loading data...")
    adata_batch = select_slide2(adata_vis, batch)
    print(f"Size {adata_batch.shape}")
    print("Computing spatial neighborhood graph...\n")
    # Compute (separate) spatial neighborhood graphs
    logging.info("sq.gr.spatial_neighbors")
    #try:
    sq.gr.spatial_neighbors(adata_batch,
                                coord_type="generic",
                                spatial_key=spatial_key,
                                n_neighs=n_neighbors)
    #except:
    #    continue
    print(f"Spatial neighbours done ## {adata_batch.shape}")

    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
print("List made: ...")
for x in adata_batch_list:
    print(x.shape)
adata_vis = ad.concat(adata_batch_list, join="inner")
# Out:
# Processing reference batches...
# Processing batch BK59_UNKNOWN_FFPE...
# Loading data...
# Size (6940, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6940, 5000)
# Processing batch BK58_UNKNOWN_FFPE...
# Loading data...
# Size (5179, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (5179, 5000)
# Processing batch BK57_UNKNOWN_FFPE...
# Loading data...
# Size (8188, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8188, 5000)
# Processing batch BK50_Past Lesional...
# Loading data...
# Size (11201, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11201, 5000)
# Processing batch BK56_UNKNOWN_FFPE...
# Loading data...
# Size (7990, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7990, 5000)
# Processing batch BK49_Past Lesional wk8 relaspe...
# Loading data...
# Size (14053, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14053, 5000)
# Processing batch BK43_wk4 Relapse...
# Loading data...
# Size (14651, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14651, 5000)
# Processing batch BK46_wk4 Relapse...
# Loading data...
# Size (14330, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14330, 5000)
# Processing batch BK46_Never Lesional...
# Loading data...
# Size (20627, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20627, 5000)
# Processing batch BK51_Past Lesional wk8 relaspe...
# Loading data...
# Size (11517, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11517, 5000)
# Processing batch BK51_Past Lesional wk4 Relapse...
# Loading data...
# Size (13754, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (13754, 5000)
# Processing batch BK51_wk8 Relapse...
# Loading data...
# Size (15262, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15262, 5000)
# Processing batch BK46_Past Lesional...
# Loading data...
# Size (20394, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20394, 5000)
# Processing batch BK43_Past Lesional...
# Loading data...
# Size (7374, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7374, 5000)
# Processing batch BK43_Never Lesional...
# Loading data...
# Size (13010, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (13010, 5000)
# Processing batch BK49_Past Lesional wk4 Relapse...
# Loading data...
# Size (21242, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (21242, 5000)
# Processing batch BK49_wk8 Relapse...
# Loading data...
# Size (12449, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (12449, 5000)
# Processing batch BK49_Past Lesional...
# Loading data...
# Size (29653, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (29653, 5000)
# Processing batch BK49_Never Lesional...
# Loading data...
# Size (14931, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14931, 5000)
# Processing batch BK51_Never Lesional...
# Loading data...
# Size (16641, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (16641, 5000)
# Processing batch BK50_Never Lesional...
# Loading data...
# Size (15391, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15391, 5000)
# Processing batch BK51_Past Lesional...
# Loading data...
# Size (15071, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15071, 5000)
# Processing batch BK50_wk4 Relapse...
# Loading data...
# Size (25506, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (25506, 5000)
# Processing batch BK22_Week 12...
# Loading data...
# Size (10115, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10115, 5000)
# Processing batch BK22_Lesional Baseline...
# Loading data...
# Size (22181, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (22181, 5000)
# Processing batch BK23_Week 12...
# Loading data...
# Size (11896, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (11896, 5000)
# Processing batch BK23_Non-lesional Baseline...
# Loading data...
# Size (19220, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (19220, 5000)
# Processing batch BK23_Day 14...
# Loading data...
# Size (9861, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9861, 5000)
# Processing batch BK23_Lesional Baseline...
# Loading data...
# Size (28742, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (28742, 5000)
# Processing batch BK22_Day 14...
# Loading data...
# Size (9732, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9732, 5000)
# Processing batch BK22_Non-lesional Baseline...
# Loading data...
# Size (9561, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9561, 5000)
# Processing batch BK22_Day 3...
# Loading data...
# Size (11639, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11639, 5000)
# Processing batch BK23_Day 3...
# Loading data...
# Size (10207, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10207, 5000)
# Processing batch BK27_Week 12...
# Loading data...
# Size (13488, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13488, 5000)
# Processing batch BK27_Day 14...
# Loading data...
# Size (8532, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8532, 5000)
# Processing batch BK21_Lesional Baseline...
# Loading data...
# Size (15564, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15564, 5000)
# Processing batch BK20_Lesional Baseline...
# Loading data...
# Size (2351, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (2351, 5000)
# Processing batch BK18_Non-lesional Baseline...
# Loading data...
# Size (7669, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7669, 5000)
# Processing batch BK21_Day 3...
# Loading data...
# Size (9017, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9017, 5000)
# Processing batch BK18_Week 12...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (15148, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15148, 5000)
# Processing batch BK20_Day 14...
# Loading data...
# Size (5708, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (5708, 5000)
# Processing batch BK27_Non-lesional Baseline...
# Loading data...
# Size (8628, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8628, 5000)
# Processing batch BK27_Lesional Baseline...
# Loading data...
# Size (7961, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (7961, 5000)
# Processing batch BK21_Day 14...
# Loading data...
# Size (10500, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (10500, 5000)
# Processing batch BK18_Lesional Baseline...
# Loading data...
# Size (17833, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (17833, 5000)
# Processing batch BK18_Day 3...
# Loading data...
# Size (14366, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14366, 5000)
# Processing batch BK27_Day 3...
# Loading data...
# Size (14697, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14697, 5000)
# Processing batch BK21_Non-lesional Baseline...
# Loading data...
# Size (6193, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6193, 5000)
# Processing batch BK20_Week 12...
# Loading data...
# Size (14999, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14999, 5000)
# Processing batch BK21_Week 12...
# Loading data...
# Size (9062, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9062, 5000)
# Processing batch BK20_Day 3...
# Loading data...
# Size (18105, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18105, 5000)
# Processing batch BK20_Non-lesional Baseline...
# Loading data...
# Size (6926, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (6926, 5000)
# Processing batch BK18_Day 14...
# Loading data...
# Size (13548, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (13548, 5000)
# Processing batch BK39_Lesional Baseline...
# Loading data...
# Size (17420, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (17420, 5000)
# Processing batch BK39_Non-lesional Baseline...
# Loading data...
# Size (17988, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17988, 5000)
# Processing batch BK39_Week 12...
# Loading data...
# Size (32597, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (32597, 5000)
# Processing batch BK25_Day 3...
# Loading data...
# Size (10294, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (10294, 5000)
# Processing batch BK25_Day 14...
# Loading data...
# Size (3957, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (3957, 5000)
# Processing batch BK25_Non-lesional Baseline...
# Loading data...
# Size (14384, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14384, 5000)
# Processing batch BK30_Day 3...
# Loading data...
# Size (8632, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (8632, 5000)
# Processing batch BK30_Day 14...
# Loading data...
# Size (32269, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (32269, 5000)
# Processing batch BK25_Lesional Baseline...
# Loading data...
# Size (12331, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12331, 5000)
# Processing batch BK25_Week 12...
# Loading data...
# Size (15240, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (15240, 5000)
# Processing batch BK24_Day 14...
# Loading data...
# Size (10219, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10219, 5000)
# Processing batch BK30_Non-lesional Baseline...
# Loading data...
# Size (18558, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18558, 5000)
# Processing batch BK30_Lesional Baseline...
# Loading data...
# Size (14739, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14739, 5000)
# Processing batch BK39_Day 14...
# Loading data...
# Size (11609, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (11609, 5000)
# Processing batch BK24_Day 3...
# Loading data...
# Size (10964, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (10964, 5000)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Processing batch BK30_Week 12...
# Loading data...
# Size (20381, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (20381, 5000)
# Processing batch BK24_Week 12...
# Loading data...
# Size (12078, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (12078, 5000)
# Processing batch BK39_Day 3...
# Loading data...
# Size (9268, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (9268, 5000)
# Processing batch BK24_Non-lesional Baseline...
# Loading data...
# Size (12726, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (12726, 5000)
# Processing batch BK24_Lesional Baseline...
# Loading data...
# Size (14242, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14242, 5000)
# Processing batch psoriasis...
# Loading data...
# Size (264502, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (264502, 5000)
# Processing batch BK68-SKI-27-FO-1-S4-B2...
# Loading data...
# Size (24602, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (24602, 5000)
# Processing batch BK58-SKI-27-FO-4-S4-A2...
# Loading data...
# Size (13190, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (13190, 5000)
# Processing batch BK58-SKI-27-FO-1-S5-A1...
# Loading data...
# Size (14011, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14011, 5000)
# Processing batch BK65-SKI-21-FO-1-S4-B1...
# Loading data...
# Size (19762, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (19762, 5000)
# Processing batch BK36-SKI-27-FO-1-S5-E1...
# Loading data...
# Size (18809, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (18809, 5000)
# Processing batch BK40-SKI-27-FO-1-S4-D2...
# Loading data...
# Size (29527, 5000)
# Computing spatial neighborhood graph...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (29527, 5000)
# Processing batch BK44-SKI-27-FO-1-S4-E2...
# Loading data...
# Size (30151, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (30151, 5000)
# Processing batch BK36-SKI-27-FO-1-S4-D1...
# Loading data...
# Size (19285, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (19285, 5000)
# Processing batch BK37-SKI-27-FO-1-S4-C1...
# Loading data...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Size (14787, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (14787, 5000)
# Processing batch BK42-SKI-27-FO-1-S4-C2...
# Loading data...
# Size (19273, 5000)
# Computing spatial neighborhood graph...
#
# Spatial neighbours done ## (19273, 5000)
# List made: ...
# (6940, 5000)
# (5179, 5000)
# (8188, 5000)
# (11201, 5000)
# (7990, 5000)
# (14053, 5000)
# (14651, 5000)
# (14330, 5000)
# (20627, 5000)
# (11517, 5000)
# (13754, 5000)
# (15262, 5000)
# (20394, 5000)
# (7374, 5000)
# (13010, 5000)
# (21242, 5000)
# (12449, 5000)
# (29653, 5000)
# (14931, 5000)
# (16641, 5000)
# (15391, 5000)
# (15071, 5000)
# (25506, 5000)
# (10115, 5000)
# (22181, 5000)
# (11896, 5000)
# (19220, 5000)
# (9861, 5000)
# (28742, 5000)
# (9732, 5000)
# (9561, 5000)
# (11639, 5000)
# (10207, 5000)
# (13488, 5000)
# (8532, 5000)
# (15564, 5000)
# (2351, 5000)
# (7669, 5000)
# (9017, 5000)
# (15148, 5000)
# (5708, 5000)
# (8628, 5000)
# (7961, 5000)
# (10500, 5000)
# (17833, 5000)
# (14366, 5000)
# (14697, 5000)
# (6193, 5000)
# (14999, 5000)
# (9062, 5000)
# (18105, 5000)
# (6926, 5000)
# (13548, 5000)
# (17420, 5000)
# (17988, 5000)
# (32597, 5000)
# (10294, 5000)
# (3957, 5000)
# (14384, 5000)
# (8632, 5000)
# (32269, 5000)
# (12331, 5000)
# (15240, 5000)
# (10219, 5000)
# (18558, 5000)
# (14739, 5000)
# (11609, 5000)
# (10964, 5000)
# (20381, 5000)
# (12078, 5000)
# (9268, 5000)
# (12726, 5000)
# (14242, 5000)
# (264502, 5000)
# (24602, 5000)
# (13190, 5000)
# (14011, 5000)
# (19762, 5000)
# (18809, 5000)
# (29527, 5000)
# (30151, 5000)
# (19285, 5000)
# (14787, 5000)
# (19273, 5000)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data

# %%
# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_vis.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_vis.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_vis.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_vis.obsp[adj_key] = sp.vstack(batch_connectivities)

# %%
sq.gr.spatial_autocorr(adata_vis, mode="moran", genes=adata_vis.var_names)

# %%
sv_genes = adata_vis.uns["moranI"].index[:n_svg].tolist()

# %%
adata_vis.var["spatially_variable"] = adata_vis.var_names.isin(sv_genes)
adata_vis.var["keep_gene"] = adata_vis.var["spatially_variable"]
adata_vis = adata_vis[:, adata_vis.var["keep_gene"] == True]
print(f"Keeping {len(adata_vis.var_names)} spatially variable, highly "
       "variable or gene program relevant genes.")
# Out:
# Keeping 1024 spatially variable, highly variable or gene program relevant genes.

# %%
import pickle
filepath = f"{handle}/svgenelist.pkl"
with open(filepath, "wb") as f:
    pickle.dump(sv_genes, f)

# %%
# sv_genes

# %%
# adata_vis
# Out:
# View of AnnData object with n_obs × n_vars = 1785932 × 1024
#     obs: 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'sample_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'xenium_id', 'xenium_id_recoded', 'Site_status', 'GSTT patient ID', 'Sanger patient ID', 'Drug', 'Responder', 'Timepoint', "Library type (CITE or 5'GEX/TCR)", 'Segmentation Y/N?', 'Sample ID', 'Xenium slide number', 'Xenium region number2', 'baseline_postrx', 'info_id', 'Annotation', 'NICHE_NAMES', 'batch', 'DonorID', 'leiden_res1', 'leiden_res2', 'new_annotation', 'new_annotation2', 'new_annotation3', 'annotation_new4', 'new_annotation4', 'new_annotation5', 'new_annotation6', 'sample', 'niche_name', 'veryfine_celltypes_new', 'niche_category', 'veryfine_celltypes_new2', 'lvl1', 'lvl0', 'veryfine_celltypes_new3', 'veryfine_celltypes_new4', 'test', 'veryfine_celltypes_new5', 'veryfine_celltypes_new5_incprolif', 'veryfine_celltypes', 'fine_celltypes_new', 'mod_celltypes_new', 'broad_celltypes_new', 'Site_status_binary', 'lvl5_annotation', 'lvl4_annotation', 'number', 'lvl3_annotation', 'Mapping_status', 'disease_overall', 'lvl0_annotation', 'lvl0_annotation2', 'lvl1_annotation', 'lvl1_annotation2', 'lvl1_annotation3', 'lvl1_annotation4', 'lvl1_annotation5', 'lvl1_annotation6', 'lvl1_annotation7', 'lvl1_annotation8', 'lvl2_annotation9', 'Annotation_tomap', 'leiden_res3', 'lvl3_annotation3', 'lvl3_annotation4', 'lvl3_annotation5', 'combined_annotation', 'combined_annotation2', 'lvl5_annotation_new3', 'lvl0_new', 'combined_annotation3', 'combined_annotation4', 'combined_annotation6', 'combined_annotation7', 'combined_annotation8', 'combined_annotation9', 'final_annotation', 'final_annotation2', 'final_annotation3', 'final_annotation4', 'final_annotation5', 'final_annotation7', 'final_annotation8', 'final_annotation9', 'final_annotation10', 'final_annotation_lvl5temp', 'niche_names', 'niche10', 'info_id2', 'final_annotation_lvl4', 'final_annotation_lvl3', 'niche11', 'final_annotation5_3', 'final_annotation5_2', 'final_annotation_lvl5_4', 'FinalXeniumScanVI_14', 'leiden_res0.1', 'FinalXeniumScanVI_16', 'FinalXeniumScanVI_17', 'niche12', 'lvl2_annotation', 'Timepoint2', 'Patient_status', 'Site_status_simple', 'updatenames1', 'updatenames2', 'updatenames3', 'lvl5_annotation_new', 'lvl5_annotation_new2', 'lvl5_annotation_new4', 'lvl5_annotation_new5', 'lvl5_annotation_new_preophan', 'lvl5_annotation_new9', 'lvl5_annotation_new12', 'lvl5_annotation_new13', 'baseline_severity', 'temp', 'lvl4_annotation_sept', 'info_id6', 'prep', 'Site_status_archive', 'response', 'response_binned', 'xenium_id_recoded2', 'RUN_ID', 'newintegration', 'scanvi_predictions', 'leiden_res0.2', 'replicate_id', 'fig8_mapping', 'all_vs_core', 'n_genes', 'sample_id_nemo', 'leiden_res0.5', 'leiden_res4', 'niche14', 'provisional', 'batch_nc'
#     var: 'spatially_variable', 'keep_gene'
#     uns: 'moranI'
#     obsm: 'X_scvi', 'X_umap', 'cell_emb', 'neighborhood_emb', 'spatial'
#     layers: 'counts'
#     obsp: 'spatial_connectivities'

# %%
adata_vis.write(ADATA_PATH + ".svg")  
print(ADATA_PATH + ".svg")
# Out:
# /lustre/scratch124/cellgen/haniffa/projects/beacon/nobackup_data/adata_mintflownonresponse.h5ad.labelled.svg

# %% [markdown]
# # Split into ref + query adatas

# %%
# ADATA_PATH= '/lustre/scratch126/cellgen/lotfollahi/ls34/nemo/adata_all.h5ad.clustered.clustered10.good.prenichecompass.svg'
# adata_vis=sc.read_h5ad(ADATA_PATH)  
# adata_vis.shape
# Out:
# (1785932, 1024)

# %%
query_batches = list(adata_vis[adata_vis.obs["batch_nc"]=="query"].obs["sample"].unique())
reference_batches = list(adata_vis[adata_vis.obs["batch_nc"]=="reference"].obs["sample"].unique())

# %%
adata_vis.obs["batch_nc"].value_counts()
# Out:
# batch_nc
# reference    1263201
# query         203397
# Name: count, dtype: int64

# %%
adata_batch_list = []
print("Processing reference batches...")
for batch in reference_batches:
    print(f"Processing batch {batch}...")
    adata_batch = select_slide2(adata_vis, batch)
    sq.gr.spatial_neighbors(adata_batch,
                                coord_type="generic",
                                spatial_key=spatial_key,
                                n_neighs=n_neighbors)
    #except:
    #    continue
    print(f"Spatial neighbours done ## {adata_batch.shape}")

    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
print("List made: ...")
for x in adata_batch_list:
    print(x.shape)
adata_reference = ad.concat(adata_batch_list, join="inner")
# Out:
# Processing reference batches...
# Processing batch BK59_UNKNOWN_FFPE...
# Spatial neighbours done ## (6940, 1024)
# Processing batch BK58_UNKNOWN_FFPE...
# Spatial neighbours done ## (5179, 1024)
# Processing batch BK57_UNKNOWN_FFPE...
# Spatial neighbours done ## (8188, 1024)
# Processing batch BK50_Past Lesional...
# Spatial neighbours done ## (11201, 1024)
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Processing batch BK56_UNKNOWN_FFPE...
# Spatial neighbours done ## (7990, 1024)
# Processing batch BK49_Past Lesional wk8 relaspe...
# Spatial neighbours done ## (14053, 1024)
# Processing batch BK43_wk4 Relapse...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (14651, 1024)
# Processing batch BK46_wk4 Relapse...
# Spatial neighbours done ## (14330, 1024)
# Processing batch BK46_Never Lesional...
# Spatial neighbours done ## (20627, 1024)
# Processing batch BK51_Past Lesional wk8 relaspe...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (11517, 1024)
# Processing batch BK51_Past Lesional wk4 Relapse...
# Spatial neighbours done ## (13754, 1024)
# Processing batch BK51_wk8 Relapse...
# Spatial neighbours done ## (15262, 1024)
# Processing batch BK46_Past Lesional...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (20394, 1024)
# Processing batch BK43_Past Lesional...
# Spatial neighbours done ## (7374, 1024)
# Processing batch BK43_Never Lesional...
# Spatial neighbours done ## (13010, 1024)
# Processing batch BK49_Past Lesional wk4 Relapse...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (21242, 1024)
# Processing batch BK49_wk8 Relapse...
# Spatial neighbours done ## (12449, 1024)
# Processing batch BK49_Past Lesional...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (29653, 1024)
# Processing batch BK49_Never Lesional...
# Spatial neighbours done ## (14931, 1024)
# Processing batch BK51_Never Lesional...
# Spatial neighbours done ## (16641, 1024)
# Processing batch BK50_Never Lesional...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (15391, 1024)
# Processing batch BK51_Past Lesional...
# Spatial neighbours done ## (15071, 1024)
# Processing batch BK50_wk4 Relapse...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (25506, 1024)
# Processing batch BK22_Week 12...
# Spatial neighbours done ## (10115, 1024)
# Processing batch BK22_Lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (22181, 1024)
# Processing batch BK23_Week 12...
# Spatial neighbours done ## (11896, 1024)
# Processing batch BK23_Non-lesional Baseline...
# Spatial neighbours done ## (19220, 1024)
# Processing batch BK23_Day 14...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (9861, 1024)
# Processing batch BK23_Lesional Baseline...
# Spatial neighbours done ## (28742, 1024)
# Processing batch BK22_Day 14...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (9732, 1024)
# Processing batch BK22_Non-lesional Baseline...
# Spatial neighbours done ## (9561, 1024)
# Processing batch BK22_Day 3...
# Spatial neighbours done ## (11639, 1024)
# Processing batch BK23_Day 3...
# Spatial neighbours done ## (10207, 1024)
# Processing batch BK27_Week 12...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (13488, 1024)
# Processing batch BK27_Day 14...
# Spatial neighbours done ## (8532, 1024)
# Processing batch BK21_Lesional Baseline...
# Spatial neighbours done ## (15564, 1024)
# Processing batch BK20_Lesional Baseline...
# Spatial neighbours done ## (2351, 1024)
# Processing batch BK18_Non-lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (7669, 1024)
# Processing batch BK21_Day 3...
# Spatial neighbours done ## (9017, 1024)
# Processing batch BK18_Week 12...
# Spatial neighbours done ## (15148, 1024)
# Processing batch BK20_Day 14...
# Spatial neighbours done ## (5708, 1024)
# Processing batch BK27_Non-lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (8628, 1024)
# Processing batch BK27_Lesional Baseline...
# Spatial neighbours done ## (7961, 1024)
# Processing batch BK21_Day 14...
# Spatial neighbours done ## (10500, 1024)
# Processing batch BK18_Lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17833, 1024)
# Processing batch BK18_Day 3...
# Spatial neighbours done ## (14366, 1024)
# Processing batch BK27_Day 3...
# Spatial neighbours done ## (14697, 1024)
# Processing batch BK21_Non-lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (6193, 1024)
# Processing batch BK20_Week 12...
# Spatial neighbours done ## (14999, 1024)
# Processing batch BK21_Week 12...
# Spatial neighbours done ## (9062, 1024)
# Processing batch BK20_Day 3...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18105, 1024)
# Processing batch BK20_Non-lesional Baseline...
# Spatial neighbours done ## (6926, 1024)
# Processing batch BK18_Day 14...
# Spatial neighbours done ## (13548, 1024)
# Processing batch BK39_Lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (17420, 1024)
# Processing batch BK39_Non-lesional Baseline...
# Spatial neighbours done ## (17988, 1024)
# Processing batch BK39_Week 12...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (32597, 1024)
# Processing batch BK25_Day 3...
# Spatial neighbours done ## (10294, 1024)
# Processing batch BK25_Day 14...
# Spatial neighbours done ## (3957, 1024)
# Processing batch BK25_Non-lesional Baseline...
# Spatial neighbours done ## (14384, 1024)
# Processing batch BK30_Day 3...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (8632, 1024)
# Processing batch BK30_Day 14...
# Spatial neighbours done ## (32269, 1024)
# Processing batch BK25_Lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (12331, 1024)
# Processing batch BK25_Week 12...
# Spatial neighbours done ## (15240, 1024)
# Processing batch BK24_Day 14...
# Spatial neighbours done ## (10219, 1024)
# Processing batch BK30_Non-lesional Baseline...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (18558, 1024)
# Processing batch BK30_Lesional Baseline...
# Spatial neighbours done ## (14739, 1024)
# Processing batch BK39_Day 14...
# Spatial neighbours done ## (11609, 1024)
# Processing batch BK24_Day 3...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (10964, 1024)
# Processing batch BK30_Week 12...
# Spatial neighbours done ## (20381, 1024)
# Processing batch BK24_Week 12...
# Spatial neighbours done ## (12078, 1024)
# Processing batch BK39_Day 3...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (9268, 1024)
# Processing batch BK24_Non-lesional Baseline...
# Spatial neighbours done ## (12726, 1024)
# Processing batch BK24_Lesional Baseline...
# Spatial neighbours done ## (14242, 1024)
# Processing batch psoriasis...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# Spatial neighbours done ## (264502, 1024)
# List made: ...
# (6940, 1024)
# (5179, 1024)
# (8188, 1024)
# (11201, 1024)
# (7990, 1024)
# (14053, 1024)
# (14651, 1024)
# (14330, 1024)
# (20627, 1024)
# (11517, 1024)
# (13754, 1024)
# (15262, 1024)
# (20394, 1024)
# (7374, 1024)
# (13010, 1024)
# (21242, 1024)
# (12449, 1024)
# (29653, 1024)
# (14931, 1024)
# (16641, 1024)
# (15391, 1024)
# (15071, 1024)
# (25506, 1024)
# (10115, 1024)
# (22181, 1024)
# (11896, 1024)
# (19220, 1024)
# (9861, 1024)
# (28742, 1024)
# (9732, 1024)
# (9561, 1024)
# (11639, 1024)
# (10207, 1024)
# (13488, 1024)
# (8532, 1024)
# (15564, 1024)
# (2351, 1024)
# (7669, 1024)
# (9017, 1024)
# (15148, 1024)
# (5708, 1024)
# (8628, 1024)
# (7961, 1024)
# (10500, 1024)
# (17833, 1024)
# (14366, 1024)
# (14697, 1024)
# (6193, 1024)
# (14999, 1024)
# (9062, 1024)
# (18105, 1024)
# (6926, 1024)
# (13548, 1024)
# (17420, 1024)
# (17988, 1024)
# (32597, 1024)
# (10294, 1024)
# (3957, 1024)
# (14384, 1024)
# (8632, 1024)
# (32269, 1024)
# (12331, 1024)
# (15240, 1024)
# (10219, 1024)
# (18558, 1024)
# (14739, 1024)
# (11609, 1024)
# (10964, 1024)
# (20381, 1024)
# (12078, 1024)
# (9268, 1024)
# (12726, 1024)
# (14242, 1024)
# (264502, 1024)

# %%
print("List made: ...", len(adata_batch_list))
for x in adata_batch_list:
    print(x.shape)
# Out:
# List made: ... 74
# (6940, 1024)
# (5179, 1024)
# (8188, 1024)
# (11201, 1024)
# (7990, 1024)
# (14053, 1024)
# (14651, 1024)
# (14330, 1024)
# (20627, 1024)
# (11517, 1024)
# (13754, 1024)
# (15262, 1024)
# (20394, 1024)
# (7374, 1024)
# (13010, 1024)
# (21242, 1024)
# (12449, 1024)
# (29653, 1024)
# (14931, 1024)
# (16641, 1024)
# (15391, 1024)
# (15071, 1024)
# (25506, 1024)
# (10115, 1024)
# (22181, 1024)
# (11896, 1024)
# (19220, 1024)
# (9861, 1024)
# (28742, 1024)
# (9732, 1024)
# (9561, 1024)
# (11639, 1024)
# (10207, 1024)
# (13488, 1024)
# (8532, 1024)
# (15564, 1024)
# (2351, 1024)
# (7669, 1024)
# (9017, 1024)
# (15148, 1024)
# (5708, 1024)
# (8628, 1024)
# (7961, 1024)
# (10500, 1024)
# (17833, 1024)
# (14366, 1024)
# (14697, 1024)
# (6193, 1024)
# (14999, 1024)
# (9062, 1024)
# (18105, 1024)
# (6926, 1024)
# (13548, 1024)
# (17420, 1024)
# (17988, 1024)
# (32597, 1024)
# (10294, 1024)
# (3957, 1024)
# (14384, 1024)
# (8632, 1024)
# (32269, 1024)
# (12331, 1024)
# (15240, 1024)
# (10219, 1024)
# (18558, 1024)
# (14739, 1024)
# (11609, 1024)
# (10964, 1024)
# (20381, 1024)
# (12078, 1024)
# (9268, 1024)
# (12726, 1024)
# (14242, 1024)
# (264502, 1024)

# %%
adata_reference = ad.concat(adata_batch_list, join="inner")

# %%
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_reference.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_reference.obsp[adj_key] = sp.vstack(batch_connectivities)

# %%
mapping_entity_key = "mapping_entity"
adata_reference.obs[mapping_entity_key] = "reference"

# %%
adata_reference.write(ADATA_PATH + ".svg.reference")  
print(ADATA_PATH + ".svg.reference")
# Out:
# /lustre/scratch124/cellgen/haniffa/projects/beacon/nobackup_data/adata_mintflownonresponse.h5ad.labelled.svg.reference

# %%
adata_vis.obs.batch_nc.value_counts()
# Out:
# batch_nc
# reference    1263201
# query         203397
# Name: count, dtype: int64

# %%
query_batches
# Out:
# ['BK68-SKI-27-FO-1-S4-B2',
#  'BK58-SKI-27-FO-4-S4-A2',
#  'BK58-SKI-27-FO-1-S5-A1',
#  'BK65-SKI-21-FO-1-S4-B1',
#  'BK36-SKI-27-FO-1-S5-E1',
#  'BK40-SKI-27-FO-1-S4-D2',
#  'BK44-SKI-27-FO-1-S4-E2',
#  'BK36-SKI-27-FO-1-S4-D1',
#  'BK37-SKI-27-FO-1-S4-C1',
#  'BK42-SKI-27-FO-1-S4-C2']

# %%
adata_batch_list = []
print("Processing query batches...")
# for batch in query_batches:
#     print(f"Processing batch {batch}...")
#     print("Loading data...")
#     adata_batch = sc.read_h5ad(
#         f"{so_data_folder_path}/{dataset}_{batch}.h5ad")
for batch in query_batches:
   # print(f"Processing batch {batch}...")
    #print("Loading data...")
    adata_batch = select_slide2(adata_vis, batch)
    #print("Computing spatial neighborhood graph...\n")
    # Compute (separate) spatial neighborhood graphs
    sq.gr.spatial_neighbors(adata_batch,
                            coord_type="generic",
                            spatial_key=spatial_key,
                            n_neighs=n_neighbors)
    
    # Make adjacency matrix symmetric
    adata_batch.obsp[adj_key] = (
        adata_batch.obsp[adj_key].maximum(
            adata_batch.obsp[adj_key].T))
    adata_batch_list.append(adata_batch)
adata_query = ad.concat(adata_batch_list, join="inner")
# Out:
# Processing query batches...
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data
# /software/cellgen/team298/ls34/vqgraph/lib/python3.10/site-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Setting element `.obsp['spatial_connectivities']` of view, initializing view as actual.
#   obj[key] = data

# %%
adata_query.obs["sample"].value_counts()
# Out:
# sample
# BK44-SKI-27-FO-1-S4-E2    30151
# BK40-SKI-27-FO-1-S4-D2    29527
# BK68-SKI-27-FO-1-S4-B2    24602
# BK65-SKI-21-FO-1-S4-B1    19762
# BK36-SKI-27-FO-1-S4-D1    19285
# BK42-SKI-27-FO-1-S4-C2    19273
# BK36-SKI-27-FO-1-S5-E1    18809
# BK37-SKI-27-FO-1-S4-C1    14787
# BK58-SKI-27-FO-1-S5-A1    14011
# BK58-SKI-27-FO-4-S4-A2    13190
# Name: count, dtype: int64

# %%
len(adata_batch_list)
# Out:
# 10

# %%
# adata_batch_list

# %%
for i in range(len(adata_batch_list)):
    print(adata_batch_list[i].shape)
# Out:
# (24602, 1024)
# (13190, 1024)
# (14011, 1024)
# (19762, 1024)
# (18809, 1024)
# (29527, 1024)
# (30151, 1024)
# (19285, 1024)
# (14787, 1024)
# (19273, 1024)

# %%
# Combine spatial neighborhood graphs as disconnected components
batch_connectivities = []
len_before_batch = 0
for i in range(len(adata_batch_list)):
    if i == 0: # first batch
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[0].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[0].shape[0])))
        batch_connectivities.append(sp.hstack(
            (adata_batch_list[0].obsp[adj_key],
            after_batch_connectivities_extension)))
    elif i == (len(adata_batch_list) - 1): # last batch
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[i].shape[0])))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key])))
    else: # middle batches
        before_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0], len_before_batch))
        after_batch_connectivities_extension = sp.csr_matrix(
            (adata_batch_list[i].shape[0],
            (adata_query.shape[0] -
            adata_batch_list[i].shape[0] -
            len_before_batch)))
        batch_connectivities.append(sp.hstack(
            (before_batch_connectivities_extension,
            adata_batch_list[i].obsp[adj_key],
            after_batch_connectivities_extension)))
    len_before_batch += adata_batch_list[i].shape[0]
adata_query.obsp[adj_key] = sp.vstack(batch_connectivities)

adata_query.obs[mapping_entity_key] = "query"

# %%
batch_connectivities = []
len_before_batch = 0

adata_query.obs[mapping_entity_key] = "query"

# %%
adata_query.write(ADATA_PATH + ".svg.query")  
print(ADATA_PATH + ".svg.query")
# Out:
# /lustre/scratch124/cellgen/haniffa/projects/beacon/nobackup_data/adata_mintflownonresponse.h5ad.labelled.svg.query

# %% [markdown]
# # this adata can now be used as input for the ref-query tutorial for
# nichecompass
# https://nichecompass.readthedocs.io/en/latest/tutorials/notebooks/mouse_cns_spatial_reference_mapping.html
#
# we apply this in a python job in ../job_scripts/nichecompass_ref_mapping2.py

# %%
STOP
# Out:
#   Cell In[43], line 1
#     .
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Results

# %%
PATH_RES = '/lustre/scratch124/cellgen/haniffa/projects/developmental_fibroblasts/nobackup_output/nichecompasss/nichecompass/artifacts/spatial_reference_mapping/20251201_091037XeniumTUTORIAL__REFQ/model/'

# %%
import os
os.listdir(PATH_RES + "reference")

# %%
PATH_RES + "reference"

# %%
import scanpy as sc
adata=sc.read_h5ad ( PATH_RES + "reference_query/adata.h5ad")
adata.obs["batch_nc"].value_counts()

# %%
# import pickle

# outpath = "/nfs/team298/ls34/skin_niche19.pkl"

# with open(outpath, "rb") as f:
#     md_loaded = pickle.load(f)

# adata.obs["niche19"] = adata.obs.index.map(md_loaded)
# adata.obs["niche19"]=adata.obs["niche19"].fillna("QUERY_DATA")

# %%
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(20,20))

sc.pl.umap(
    adata,
    color=[
        "batch_nc",
    ],
    #legend_loc="on data",
    s=10,
    legend_fontsize=54,
    legend_fontoutline=2,
    show=False,
    #palette=colorsmap,
    edgecolor='black',
    linewidth=0.01,
    title='',
    palette=['lightblue', 'orange']
#   save=f"{x}_PAGA.pdf"
)

# %%
colors_new2 = {
        'Epidermis_basal': "#4a538f",# "#3489f1", #"#000080", #"#f0f8ff", #"#007cfe",#'#4f59a1',  # dark blue
    "Epidermis basal":"#3489f1",# "#000080", #"#f0f8ff", #"#000080",
    
                'Epidermis_mid': '#F0F8FF', # #e3e7eb - GREY
  #  "Epidermis_late": "#4682B4", #"#A52A2A",          # pink
            'Epidermis_late':"#2a2f5c",#"#2a2f5c" ,# "#2e2e2e",#'#b1dae6',  # light blue

   'Epidermis basal_cycling': "#007cfe",  #  e2d8dd   "#505aa1",#"#c590a5" , # '#e0c5d2',
'Epidermis_basal_cycling': "#007cfe", 
'EpidermisInflamm_mid':"#f6e3ec",
        'EpidermisInflamm_late': "#800020",
    
    
    # 'Epidermis_Inflammatory': '#f2e7ed',
        "Epidermis_APChi": "#ff1493",
    'Papillary_dermis':"#FFFF00", # "#f6d17a", # yellow
    
  #  'Perivascular':  "#845DAE", #  '#fedbe7' PINKSIH,  #'#f8daeb',  # darkish red
    'Small blood vessel': "#d73435", #'#fe78bb',  # bright red
    'Sweat_gland': '#008080',  # dark grey
        'Sweat_gland_channel': "#adf7e8", #'#008080',  # original - 40E0D0
    'Muscle': "#f371af",  # very dark red
    'Adipocyte+vessels': "#B8860B", #'#FF4500',  # very dark orange
     'Hypodermis': "#FFFFF0", #"#D2B48C",#' # yello  # white = '#ffffff',
    'Larger blood vessel': "#660000",#"#8B0000", #'#FF6347',  # coral red
    'Perineural': '#0A0A0A',  # almost black
   # 'Plasma+pDC': '#808080',  # bright turquoise
    #'Sweat gland channel': '#000000',  # black
    #'KC_immunecell': '#FF1493',  # dark pink
    
   # 'Epidermis_late': '#b1dae6',
    "Nonspecific":"#D3D3D3",
     'Reticular_dermis': '#d0e1f2',

 'Large_BV': '#660000',
 'Small_BV': "#c43f40",#'#D96B6B',
     'Tzone-like': "#845DAE",# '#F4D1A1',

 'Sebaceous_gland': "#FFD9A3",      #  "#FFB347",#"#94cb72",#'#e28743',
"Sebaceous_immune": "#ff6145", 
 #'Plasma_cell_niche': "#1F51FF", #"#FFB300",#"#40E0D0",#'#ff5e00',
   # 'Plasma_cell_rich':  "#8080B2", #"
"Plasma_cell_rich": "#04D9FF",
    'HF_Perineural': '#00FF00',
    "OuterHF": "#006600",# 
 'Sebaceous duct': '#e28743',


"Lymphoid Tzone-like": "#825bac",
    



     #007FFF
    "Reticular_dermis_LE_rich" : "#6A8ED8",
        "Reticular_dermis_LErich" : "#6A8ED8",
    "Small_BV_Trich": "#FFB6C1",          # neon orange
    "Tzone-like_Theavy": "#B19CD9",       # light purple
    #"Reticular dermis_F2/F3hi": "#35476C", #"#FF5F1F",# light blue
    "HF_outer": "#90c670",                # very dark green
    "VenuleMuscle": "#B34A7E",

    "Sebaceous_duct": "#FFA07A",          # light orange (salmony)
    "VenuleEndothelium": "#8B0000",       # dark red
    "HF_inner": "#90EE90",                 # light green
    "HF_TNN+COCH+hi": "#39FF14",          # neon green
    # "Peri_sweat_gland": "#d9f9f7",
    'HF_innermost':  "#D95D54",
  #  'Sebaceous_inner_immune':"#F6A85C",
    'Nonspecific/folded': "#F0F0F0",
 'nan': '#FAFAFA',
    "QUERY_DATA": '#F0F0F0'
    }

# %%
"""
how do niches compare to what we had before
"""
sc.pl.umap(
    adata,
    color=[
        "niche19",
    ],
    legend_loc="on data",
    s=5,
    legend_fontsize=14,
    legend_fontoutline=2,
    show=False,
    #palette=colorsmap,
    edgecolor='black',
    linewidth=0.01,
    title='',
    palette=colors_new2,
#   save=f"{x}_PAGA.pdf"
)

# %%
"""
how do niches compare to what we had before
"""
sc.pl.umap(
    adata,
    color=[
        "niche19",
    ],
   # legend_loc="on data",
    s=5,
    legend_fontsize=14,
    legend_fontoutline=2,
    show=False,
    #palette=colorsmap,
    edgecolor='black',
    linewidth=0.01,
    title='',
    palette=colors_new2,
#   save=f"{x}_PAGA.pdf"
)

# %%
# adata.write( PATH_RES + "reference_query/adata.h5ad")
