# %%
#import numpy as np
#import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns
import scanpy as sc
#import squidpy as sq
#import anndata as ad
import pickle
import gc
#%matplotlib inline
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(8,8))

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
#%matplotlib inline
sc.settings.figdir = "fig3"
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(8,8))

# %%
NICHE="niche19"

# %% [markdown]
# # Latest

# %%
PATH = '/nfs/team298/ls34/adult_skin/final_adatas/adata_combined_inc_relapse_webportal.h5ad'
adata_5k=sc.read_h5ad(PATH)
adata_5k=adata_5k[adata_5k.obs["tech"]=="xenium"].copy()
gc.collect()
# Out:
# 1211

# %%
with open('/nfs/team298/ls34/niche_colors.pkl', 'rb') as f:
    colors_loaded = pickle.load(f)

# %%
for x in [ 'BK39_Lesional Baseline',  'BK22_Lesional Baseline',
          'Lesional_CE3-SKI-24-FO-1-S22-A1',
        #  'Lesional_Baseline_resolved_CE3-SKI-24-FO-1-S22_replicate',
          # 'Lesional_CE3-SKI-24-FO-1-S22_replicate',
           'Lesional_CE4-SKI-27-FO-4-S22-A2',
      #'Lesional_CE4-SKI-27-FO-4-S22_replicate',

         ]:
    adata_i=adata_5k[adata_5k.obs["info_id6"]==x]

    # adata_i.obs[NICHE] =adata_i.obs[NICHE] .astype('category')
    # adata_i.uns[NICHE+'_colors'] = [colors_loaded.get(cat, '#D3D3D3')   
    #                                      for cat in adata_i.obs[NICHE].cat.categories]
    # # adata_i.obs['niche17_alt2'] =adata_i.obs['niche17_alt2'] .astype('category')
    # adata_i.uns['niche17_alt2_colors'] = [colors_loaded.get(cat, '#D3D3D3')   
    #                                      for cat in adata_i.obs['niche17_alt2'].cat.categories]
    sc.pl.spatial(
        adata_i,#[adata_i.obs["Timepoint"].str.startswith("Les")],
       # library_id="spatial",
      #  shape=None,
        color=[NICHE],
        spot_size=10,
        vmax=1,
                edgecolor="black",
        linewidth=0.05,
                legend_fontsize=12,
        title=x,
        legend_loc=None,
        save=f"fig3b_niches_{x}.pdf",
        palette=colors_loaded
       
    )
# Out:
# /tmp/ipykernel_3771433/706009732.py:17: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# /nfs/users/nfs_l/ls34/.local/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[f"{value_to_plot}_colors"] = colors_list
# WARNING: saving figure to file fig3/showfig3b_niches_BK39_Lesional Baseline.pdf
# /tmp/ipykernel_3771433/706009732.py:17: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# /nfs/users/nfs_l/ls34/.local/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[f"{value_to_plot}_colors"] = colors_list
# WARNING: saving figure to file fig3/showfig3b_niches_BK22_Lesional Baseline.pdf
# /tmp/ipykernel_3771433/706009732.py:17: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# /nfs/users/nfs_l/ls34/.local/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[f"{value_to_plot}_colors"] = colors_list
# WARNING: saving figure to file fig3/showfig3b_niches_Lesional_CE3-SKI-24-FO-1-S22-A1.pdf
# /tmp/ipykernel_3771433/706009732.py:17: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# /nfs/users/nfs_l/ls34/.local/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[f"{value_to_plot}_colors"] = colors_list
# WARNING: saving figure to file fig3/showfig3b_niches_Lesional_CE4-SKI-27-FO-4-S22-A2.pdf

# %%
for x in [ #'BK39_Lesional Baseline', 
    'BK22_Lesional Baseline',
          'Lesional_CE3-SKI-24-FO-1-S22-A1', 
        #   'Lesional_CE4-SKI-27-FO-4-S22-A2',
 
         ]:
    adata_i=adata_5k[adata_5k.obs["info_id6"]==x]

    # adata_i.obs[NICHE] =adata_i.obs[NICHE] .astype('category')
    # adata_i.uns[NICHE+'_colors'] = [colors_loaded.get(cat, '#D3D3D3')   
    #                                      for cat in adata_i.obs[NICHE].cat.categories]
    # # adata_i.obs['niche17_alt2'] =adata_i.obs['niche17_alt2'] .astype('category')
    # adata_i.uns['niche17_alt2_colors'] = [colors_loaded.get(cat, '#D3D3D3')   
    #                                      for cat in adata_i.obs['niche17_alt2'].cat.categories]
    sc.pl.spatial(
        adata_i,#[adata_i.obs["Timepoint"].str.startswith("Les")],
       # library_id="spatial",
      #  shape=None,
        color=[NICHE],
        spot_size=10,
        vmax=1,
                edgecolor="black",
        linewidth=0.05,
                legend_fontsize=12,
        title=x,
        #legend_loc=True,
        save=f"fig3b_niches_{x}_legend.pdf",
        palette=colors_loaded
       
    )
# Out:
# /tmp/ipykernel_3771433/3141096824.py:15: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# /nfs/users/nfs_l/ls34/.local/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[f"{value_to_plot}_colors"] = colors_list
# WARNING: saving figure to file fig3/showfig3b_niches_BK22_Lesional Baseline_legend.pdf
# /tmp/ipykernel_3771433/3141096824.py:15: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# /nfs/users/nfs_l/ls34/.local/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[f"{value_to_plot}_colors"] = colors_list
# WARNING: saving figure to file fig3/showfig3b_niches_Lesional_CE3-SKI-24-FO-1-S22-A1_legend.pdf

# %% [markdown]
# # LEGEND FOR PLOT

# %%
adata_i.obs[NICHE].value_counts()
# Out:
# niche19
# EpidermisInflamm_mid        9402
# Small_BV                    3187
# Papillary_dermis            2615
# Tzone-like                  1823
# Reticular_dermis            1263
# EpidermisInflamm_upper       981
# Sebaceous_duct               891
# Epidermis_upper              830
# Reticular_dermis_LE_rich     397
# Muscle                       326
# Large_BV                     183
# Epidermis_basal               75
# Sweat_gland                   61
# Sweat_gland_channel           57
# Epidermis_mid                 13
# Perineural                    12
# VenuleMuscle                   7
# Epidermis_APChi                1
# Name: count, dtype: int64

# %%
ALL = ['BK39_Lesional Baseline',  'BK22_Lesional Baseline',
          'Lesional_CE3-SKI-24-FO-1-S22-A1',
        #  'Lesional_Baseline_resolved_CE3-SKI-24-FO-1-S22_replicate',
          # 'Lesional_CE3-SKI-24-FO-1-S22_replicate',
           'Lesional_CE4-SKI-27-FO-4-S22-A2',
      #'Lesional_CE4-SKI-27-FO-4-S22_replicate',

         ]
adata_i=adata_5k[adata_5k.obs["info_id6"].isin(ALL)]

sc.pl.spatial(
        adata_i,#[adata_i.obs["Timepoint"].str.startswith("Les")],
       # library_id="spatial",
      #  shape=None,
        color=[NICHE],
        spot_size=10,
        vmax=1,
                edgecolor="black",
        linewidth=0.05,
                legend_fontsize=12,
        title=x,
        #legend_loc=None,
        save=f"fig3b_niches_LEGEND.pdf",
       
    )
# Out:
# /tmp/ipykernel_3771433/3574367073.py:11: FutureWarning: Use `squidpy.pl.spatial_scatter` instead.
#   sc.pl.spatial(
# WARNING: saving figure to file fig3/showfig3b_niches_LEGEND.pdf
