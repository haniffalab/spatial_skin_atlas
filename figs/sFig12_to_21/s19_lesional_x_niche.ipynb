# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import scanpy as sc
import matplotlib.gridspec as gridspec
import pickle

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
#%matplotlib inline
sc.settings.figdir = "supp"
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(25,25))

# %% [markdown]
# # Load data

# %%
FILE_NAME = "adata_combined_new.h5ad.final.filtered.addrelapse"
PATH2=f'/nfs/team298/ls34/adult_skin/final_adatas/{FILE_NAME}'
adata_5k=sc.read_h5ad(PATH2)
adata_5k=adata_5k[adata_5k.obs["tech"]=="xenium"]

def remove_markers(LIST):
    try: 
        LIST = {key: [gene for gene in genes if gene in adata_5k.var_names] 
                           for key, genes in LIST.items()}
    except: 
        LIST =[gene for gene in LIST if gene in adata_5k.var_names]
    return LIST


 
adata_5k.obs["lvl5_annotation"]=adata_5k.obs["lvl4_annotation"]
# Out:
# /tmp/ipykernel_2726021/1567949325.py:16: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_5k.obs["lvl5_annotation"]=adata_5k.obs["lvl4_annotation"]

# %% [markdown]
# # Remove niche where skin folded

# %%
adata_5k=adata_5k[adata_5k.obs["niche19"]!= 'Nonspecific/folded'].copy()
NICHE = "niche19"
adata_5k.obs["niche19"].value_counts()
# Out:
# niche19
# Small_BV                    339019
# Papillary_dermis            232277
# Epidermis_basal             187685
# Epidermis_mid               138486
# Reticular_dermis            119265
# Epidermis_upper             109777
# Tzone-like                   81392
# EpidermisInflamm_mid         73634
# Sweat_gland                  50570
# Sweat_gland_channel          49393
# Muscle                       44360
# Sebaceous_duct               38483
# Epidermis_late               32864
# Large_BV                     29715
# Reticular_dermis_LE_rich     26229
# Perineural                   23437
# HF_outer                     22859
# Hypodermis                   16997
# Sebaceous_gland              15827
# VenuleMuscle                 14906
# Epidermis_basal_cycling      10415
# EpidermisInflamm_upper        4396
# Sebaceous_immune              3459
# HF_inner                      2424
# Epidermis_APChi                664
# Plasma_cell_rich               566
# HF_innermost                   119
# Name: count, dtype: int64

# %%
# [x for x in adata_5k.obs["lvl5_annotation"].unique() if x.startswith("ILC")]

# %%
adata_5k.obs["Site_status"].value_counts()
# Out:
# Site_status
# Lesional                            205777
# Non-lesional                        192948
# 3D_Week12                           179026
# 3D_Lesional_baseline                153479
# Week 12                             149279
# Remission_longterm (past)           140285
# Remission_longterm (never)          127032
# Relapse                             102198
# Psoriasis_replicate_non-lesional     76048
# Week 8 Psoriasis                     72092
# Remission_longterm (week 8)          71279
# Psoriasis_replicate_Lesional         60640
# Healthy                              59315
# Psoriasis_replicate_PostRx           49382
# Day 14_HF                            30438
# Name: count, dtype: int64

# %%
CATEGORY="lvl5_annotation"

# %% [markdown]
# # Compare niche composition

# %%
adata_5k_i = adata_5k[          (adata_5k.obs["Site_status"].str.startswith("Lesional"))|
                    (adata_5k.obs["disease_overall"].str.startswith("3D_Lesional_baseline"))|

                    (adata_5k.obs["Site_status"].str.startswith("Psoriasis_replicate_Lesional"))
                                          
   
      # (adata_5k.obs["Site_status"]=="Healthy")
                   ]

# %%
adata_5k_i
# Out:
# View of AnnData object with n_obs × n_vars = 266417 × 4993
#     obs: 'sample_id', 'barcode', 'GSE', 'Site_status', 'Patient_status', 'Location', 'Age', 'Sex', 'dataset_id', 'n_genes_by_counts', 'total_counts', 'pct_counts_in_top_50_genes', 'lvl5_annotation', 'Mapping_status', 'scanvi_predictions', 'lvl4_annotation', 'lvl0', 'Site_status_simple', 'StatusMilo', 'atlas_status', 'atlas_status_reynolds', 'atlas_status_reynolds_simple', 'atlas_status_simple', 'atlas_status_simple2', 'Site_status_binary', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'Sanger patient ID', 'Drug', 'Timepoint', 'DonorID', 'disease_overall', 'lvl0_new', 'Timepoint2', 'baseline_severity', 'info_id6', 'response', 'all_vs_core', 'tech', 'scanvi_predictions2', 'lvl1_new', 'niche19', 'data_addition'
#     obsm: 'X_scvi', 'X_umap', 'spatial'

# %%
path = "/nfs/team298/ls34/niche_colors.pkl"
with open(path, "rb") as f:
    colors_new2 = pickle.load(f)

path = "/nfs/team298/ls34/niche_colors.pkl"
with open(path, "rb") as f:
    colors_new2 = pickle.load(f)
colors=colors_new2

# %%
import matplotlib.pyplot as plt
import pandas as pd

diseases = adata_5k_i.obs["disease_overall"].unique()

fig, axes = plt.subplots(1, len(diseases), figsize=(7 * len(diseases), 1), sharey=True)

if len(diseases) == 1:
    axes = [axes]

for ax, disease in zip(axes, sorted(diseases)):
    sub = adata_5k_i.obs.loc[adata_5k_i.obs["disease_overall"] == disease]
    props = sub["niche19"].value_counts(normalize=True).sort_index()

    ax.bar(range(len(props)), props.values,
           color=[colors.get(c, "#999999") for c in props.index],
           edgecolor="none")
    ax.set_xticks(range(len(props)))
    ax.set_xticklabels(props.index, rotation=90, ha="center")
    ax.set_title(disease)
    ax.set_xlabel("")

    ax.set_ylabel("Proportion" if ax == axes[0] else "")
    ax.spines[["top", "right"]].set_visible(False)
    ax.grid(False)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2726021/2363760676.py:27: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import pandas as pd

desired_order = [
     'Epidermis_APChi',
    'EpidermisInflamm_upper',
    'EpidermisInflamm_mid',
    'Epidermis_basal_cycling',
    'Epidermis_upper',
    'Epidermis_mid',
    'Epidermis_basal',
    'Papillary_dermis',
    'Small_BV',
    'Tzone-like',
    'Reticular_dermis',
    # 'Reticular_dermis_LErich',
    'Reticular_dermis_LE_rich',
    'Large_BV',
    'VenuleMuscle',
    'Perineural',
    # 'HF',
    # 'OuterHF',
    'HF_outer',
    'HF_inner',
     'HF_innermost',
    'Muscle',
    'Sebaceous_gland',
    'Sebaceous_duct',
    'Sebaceous_immune',
    'Plasma_cell_rich',
    # 'Plasma_cell_niche',
    'Sweat_gland',
    'Sweat_gland_channel',
    # 'Sebaceous_immune',
    # 'Epidermis_APChi',
    'Hypodermis',
    # 'Perifollicular_VE',
    # 'Epidermis_basal_immune'
]

# --- Sanity check: report mismatches between data and desired_order ---
all_niches_in_data = set(adata_5k_i.obs["niche19"].unique())
desired_set = set(desired_order)

in_data_not_in_order = sorted(all_niches_in_data - desired_set)
in_order_not_in_data = sorted(desired_set - all_niches_in_data)

if in_data_not_in_order:
    print("⚠️  Niches present in data but NOT in desired_order (will be dropped from plot):")
    for n in in_data_not_in_order:
        print(f"    - {n}")
else:
    print("✓ All niches in the data are listed in desired_order.")

if in_order_not_in_data:
    print("\nℹ️  Niches in desired_order but NOT present in data (will simply be absent):")
    for n in in_order_not_in_data:
        print(f"    - {n}")

# --- Plot ---
diseases = adata_5k_i.obs["disease_overall"].unique()
fig, axes = plt.subplots(1, len(diseases),
                         figsize=(7 * len(diseases), 1),
                         sharey=True)
if len(diseases) == 1:
    axes = [axes]

for ax, disease in zip(axes, sorted(diseases)):
    sub = adata_5k_i.obs.loc[adata_5k_i.obs["disease_overall"] == disease]
    props_raw = sub["niche19"].value_counts(normalize=True)

    # Reindex to desired_order; niches not present in this disease get 0
    # Only keep niches that are actually in desired_order (drops extras)
    props = props_raw.reindex(desired_order, fill_value=0)

    ax.bar(range(len(props)), props.values,
           color=[colors.get(c, "#999999") for c in props.index],
           edgecolor="none")
    ax.set_xticks(range(len(props)))
    ax.set_xticklabels(props.index, rotation=90, ha="center")
    ax.set_title(disease)
    ax.set_xlabel("")
    ax.set_ylabel("Proportion" if ax == axes[0] else "")
    ax.spines[["top", "right"]].set_visible(False)
    ax.grid(False)

plt.tight_layout()
plt.show()
# Out:
# ✓ All niches in the data are listed in desired_order.
# /tmp/ipykernel_2726021/4136859632.py:87: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
props_raw
# Out:
# niche19
# EpidermisInflamm_mid        0.277975
# Small_BV                    0.161273
# Papillary_dermis            0.137227
# Tzone-like                  0.101877
# Epidermis_basal             0.056578
# Reticular_dermis            0.041068
# Epidermis_upper             0.039834
# EpidermisInflamm_upper      0.032034
# HF_outer                    0.025965
# Sebaceous_duct              0.023360
# Muscle                      0.019644
# Large_BV                    0.019505
# Reticular_dermis_LE_rich    0.015462
# Perineural                  0.012832
# Sweat_gland_channel         0.011419
# Sweat_gland                 0.008225
# Sebaceous_immune            0.004942
# Sebaceous_gland             0.004541
# Hypodermis                  0.002369
# Epidermis_mid               0.002017
# HF_innermost                0.000939
# HF_inner                    0.000408
# VenuleMuscle                0.000180
# Epidermis_basal_cycling     0.000172
# Epidermis_APChi             0.000155
# Plasma_cell_rich            0.000000
# Name: proportion, dtype: float64

# %%
# --- Plot ---
diseases = adata_5k_i.obs["disease_overall"].unique()
fig, axes = plt.subplots(1, len(diseases),
                         figsize=(7 * len(diseases), 1),
                         sharey=True)
if len(diseases) == 1:
    axes = [axes]

for ax, disease in zip(axes, sorted(diseases)):
    sub = adata_5k_i.obs.loc[adata_5k_i.obs["disease_overall"] == disease]
    props_raw = sub["niche19"].value_counts(normalize=True)

    # Reindex to desired_order; niches not present in this disease get 0
    # Only keep niches that are actually in desired_order (drops extras)
    props = props_raw.reindex(desired_order, fill_value=0)

    ax.bar(range(len(props)), props.values,
           color=[colors.get(c, "#999999") for c in props.index],
           edgecolor="black")
    ax.set_xticks(range(len(props)))
    ax.set_xticklabels(props.index, rotation=90, ha="center", fontsize=7)
    ax.set_title("", fontsize=0, #pad=20
                )
    ax.set_xlabel("")
    ax.set_ylabel("Proportion" if ax == axes[0] else "", fontsize=8)
    ax.set_xticklabels(props.index, rotation=90, ha="center", fontsize=7)

    ax.spines[["top", "right"]].set_visible(False)
    ax.grid(False)

plt.tight_layout()
plt.savefig("./Supp19A.pdf", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_2726021/1603633414.py:31: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Recreate the figure in THIS cell
# diseases = adata_5k_i.obs["disease_overall"].unique()
# fig, axes = plt.subplots(1, len(diseases),
#                          figsize=(7 * len(diseases), 2),  
#                          sharey=True)
# if len(diseases) == 1:
#     axes = [axes]

# for ax, disease in zip(axes, sorted(diseases)):
#     sub = adata_5k_i.obs.loc[adata_5k_i.obs["disease_overall"] == disease]
#     props_raw = sub["niche19"].value_counts(normalize=True)
#     props = props_raw.reindex(desired_order, fill_value=0)

#     plot_vals = props.replace(0, np.nan)

#     ax.bar(range(len(props)), plot_vals.values,
#            color=[colors.get(c, "#999999") for c in props.index],
#            edgecolor="none")
#     ax.set_yscale("log")
#     ax.set_ylim(1e-4, 1)

#     ax.set_xticks(range(len(props)))
#     ax.set_xticklabels(props.index, rotation=90, ha="center", fontsize=7)
#     ax.set_title(disease, fontsize=9, pad=20)
#     ax.set_ylabel("Proportion (log)" if ax == axes[0] else "", fontsize=8)
#     ax.spines[["top", "right"]].set_visible(False)
#     ax.grid(False)

# plt.tight_layout()
# plt.savefig("Supp19A.pdf", dpi=300, bbox_inches="tight")
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# diseases = adata_5k_i.obs["disease_overall"].unique()
# fig, axes = plt.subplots(1, len(diseases), figsize=(7 * len(diseases), 1), sharey=True)
# if len(diseases) == 1:
#     axes = [axes]

# for ax, disease in zip(axes, sorted(diseases)):
#     sub = adata_5k_i.obs.loc[adata_5k_i.obs["disease_overall"] == disease]
#     props = sub["niche19"].value_counts(normalize=True).sort_index()
#     ax.bar(range(len(props)), props.values,
#            color=[colors.get(c, "#999999") for c in props.index],
#            edgecolor="none")
#     ax.set_xticks(range(len(props)))
#     ax.set_xticklabels(props.index, rotation=90, ha="center", fontsize=7)
#     ax.set_title(disease, fontsize=9, pad=20)
#     ax.set_xlabel("")
#     ax.set_ylabel("Proportion" if ax == axes[0] else "", fontsize=8)
  #  ax.set_xticklabels(props.index, rotation=90, ha="center", fontsize=7)
#     ax.spines[["top", "right"]].set_visible(False)
#     ax.grid(False)

# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.patches import Patch

diseases = adata_5k_i.obs["disease_overall"].unique()
fig, axes = plt.subplots(1, len(diseases), figsize=(7 * len(diseases), 3), sharey=True)

if len(diseases) == 1:
    axes = [axes]

all_niches = sorted(adata_5k_i.obs["niche19"].unique())

for ax, disease in zip(axes, sorted(diseases)):
    sub = adata_5k_i.obs.loc[adata_5k_i.obs["disease_overall"] == disease]
    props = sub["niche19"].value_counts(normalize=True).sort_index()
    ax.bar(range(len(props)), props.values,
           color=[colors.get(c, "#999999") for c in props.index],
           edgecolor="none")
    ax.set_xticks([])
    ax.set_title(disease)
    ax.set_xlabel("")
    ax.set_ylabel("Proportion" if ax == axes[0] else "")
    ax.spines[["top", "right"]].set_visible(False)
    ax.grid(False)

legend_handles = [Patch(facecolor=colors.get(n, "#999999"), edgecolor="none", label=n)
                  for n in all_niches]
fig.legend(handles=legend_handles, bbox_to_anchor=(1.01, 1), loc="upper left",
           frameon=False, fontsize="small", ncols=4)

plt.tight_layout()
plt.show()

# %%
# df = 

# counts = (
#     df.groupby(["disease_overall", "niche19"])
#       .size()
#       .reset_index(name="count")
# )



# total_counts = counts.groupby("disease_overall")["count"].sum().reset_index(name="total")
# counts = counts.merge(total_counts, on="disease_overall")
# counts["prop"] = counts["count"] / counts["total"]

# niche_order = counts["niche19"].unique()

# plot_df = counts.pivot_table(
#     index="disease_overall",
#     columns="niche19",
#     values="prop",
#     fill_value=0
# )[niche_order].reset_index()

# fig, ax = plt.subplots(figsize=(14, 3.5))  # Increased height slightly for space below

# x_offsets = np.zeros(len(plot_df))
# fallback = "#d3d3d3"
# colors = [colors_new2.get(n, fallback) for n in niche_order]

# for i, niche in enumerate(niche_order):
#     props = plot_df[niche].values
#     ax.barh(
#         y=plot_df["disease_overall"],
#         width=props,
#         left=x_offsets,
#         color=colors[i],
#         edgecolor="white",
#         label=niche
#     )
#     x_offsets += props

# ax.set_xlabel("Proportion of cells in niche")
# ax.set_xlim(0, 1)
# ax.spines["top"].set_visible(False)
# ax.spines["right"].set_visible(False)
# ax.grid(False)
# ax.set_title("Niche composition by disease")

# n_cols = int(np.ceil(len(niche_order) / 2))
# ax.legend(
#     bbox_to_anchor=(0.5, -0.35),  # Below plot
#     loc="upper center",
#     ncol=n_cols,
#     fontsize=7,
#     title="Niche",
#     frameon=False
# )

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Lesional cell contents

# %%
# adata_5k_i.obs.Site_status_binary.value_counts()
# adata_5k_i=adata_5k[(adata_5k.obs["Site_status"]=="Lesional")
#                 # (adata_5k.obs["Site_status"].str.startswith("Psoriasis_replicate_non-lesional"))
#                    ]
adata_5k_i.obs.Site_status.value_counts()
# Out:
# Site_status
# Lesional                        205777
# Psoriasis_replicate_Lesional     60640
# Name: count, dtype: int64

# %%
adata_5k.obs["niche19"].value_counts()
# Out:
# niche19
# Small_BV                    339019
# Papillary_dermis            232277
# Epidermis_basal             187685
# Epidermis_mid               138486
# Reticular_dermis            119265
# Epidermis_upper             109777
# Tzone-like                   81392
# EpidermisInflamm_mid         73634
# Sweat_gland                  50570
# Sweat_gland_channel          49393
# Muscle                       44360
# Sebaceous_duct               38483
# Epidermis_late               32864
# Large_BV                     29715
# Reticular_dermis_LE_rich     26229
# Perineural                   23437
# HF_outer                     22859
# Hypodermis                   16997
# Sebaceous_gland              15827
# VenuleMuscle                 14906
# Epidermis_basal_cycling      10415
# EpidermisInflamm_upper        4396
# Sebaceous_immune              3459
# HF_inner                      2424
# Epidermis_APChi                664
# Plasma_cell_rich               566
# HF_innermost                   119
# Name: count, dtype: int64

# %%
adata_5k_i = adata_5k_i[(adata_5k_i.obs["lvl0"].str.startswith("T"))|
                     (adata_5k_i.obs[CATEGORY].str.startswith("Plasm"))|
                        (adata_5k_i.obs[CATEGORY].str.startswith("Bcell"))|
                     (adata_5k_i.obs["lvl0"]=="Myeloid")|
                         (adata_5k_i.obs[CATEGORY]=="Mast cell") |
                      (adata_5k_i.obs[CATEGORY]=="LC_ALOX15hi") 
                      

#                (adata_5k.obs["lvl0"]=="Melanocyte")|
 #               (adata_5k.obs["lvl0"]=="Adipocyte")|
  #             (adata_5k.obs["lvl0"]=="Mast cell")|
   #                (adata_5k.obs["lvl0"]=="Plasma cell/Bcell")
               ]
adata_5k_i.shape

desired_order2 =  ['Treg','Treg_LRRC32','Treg_LRRC32+', 'TR1', 'Tnaive','Tnaive1','Tnaive2', 'Tnaive/T_cm', 'Tnaive/Tcm', 'T_polarized_CCR6+','Th', 
                  'Th_PPARGhi',
                  'Th_PPARGhi_IL17+',
                  'Tc',
                 'Tc_IFNGhi',"Tc_ZNF683+",'T_γδ',
            'Tc_IL13','TRM_IL13',"TRM_IL13+",
'TRM_IL17', "TRM_IL17+",'Th/TRM prolif', 'T','T_polarized',
                
                 







                
                 'T_Prolif','T_prolif','Treg/Tnaive_prolif',

'NK', "ILC1/NK","ILC_prolif",
                 
'ILC_Prolif',
          

'ILC1','ILC1_NCR2+P2RX7+','ILC3',
                  'ILC3_CCL1+PTGDS+', 
                  
                          'ILC2',
                  
                  
                'Plasma cell',
                  "Monocyte",
                  'Monocyte?', 'Mac',
                   
                   
                   
                   
                   'Macint','Mac_TREM2+LPL+',
                   
                   
                'Mac1',  'Mac2',


'Tc0','Tc1','Tc2','Tc3_IFNGhi',

                   'Tc_Prolif' ,




 'Mac2_CCL14hi','Mac_CCL14hi','MacCCL14_hi','Mac_LPLhi', 'Mac LPLhi (P2RY12-)',
                  'Mac LPLhi','Mac_TREM+','Mac_Perineural?',"Mac_CX3CR1+",
                  'Mac_prolif/PreDC', 'TransitionalDC',
                   "Mac_prolif/preDC",
'Mac_prolif',
















'cDC',
 'cDC1',
 'cDC2', 'cDC2_MMP12',   'cDC2: MMP12+', 'cDC2: MMP12hi', "cDC2: MMP12+IL1B+",'cDC2: THBS1+', 'cDC2: EREG+CCR7+', 'cDC2_cycling',
                  'MoDC/cDC2','MoDC','cDC2_MoDC(C1QTNF1+KDR+)','cDC2_MoDC (THBS1+)', 'cDC2_THBS1+','LC/MoDC_MMP12+/CXCL9+',
                  'cMoDC/cDC (C1QTNF1+KDR+)','MoDC?','MoDC_lowqithink?',

                   'LC_CCR7+','LC_SLC18A2+',
 'LC','LC_ALOX15hi',
'cDC2_MMP12hi (Mig)','cDC: MMP12+/CXCL9+', 
 'MigDC','MigDC_T_doublet',
                  'MigDC (cDC1)','MigDC (cDC2)',
 'pDC',"Mast cell", "Neutrophil",
                 
                  'DC2/Mac',
                  "Bcell",



 

]


# Ensure 'lvl3_annotation' is categorical
if not pd.api.types.is_categorical_dtype(adata_5k_i.obs[CATEGORY]):
    adata_5k_i.obs[CATEGORY] = adata_5k_i.obs[CATEGORY].astype('category')

    
if not pd.api.types.is_categorical_dtype(adata_5k_i.obs[CATEGORY]):
    adata_5k_i.obs[CATEGORY] = adata_5k_i.obs[CATEGORY].astype('category')

missing_data = 0
for x in list(adata_5k_i.obs[CATEGORY].unique()):
    if x not in desired_order2:
        print(x)
        missing_data +=1
if missing_data != 0:
    stop
        
        
# Set the categories in the desired order
adata_5k_i.obs[CATEGORY] = pd.Categorical(
    adata_5k_i.obs[CATEGORY],
    categories=desired_order2,
    ordered=True
)
# Out:
# /tmp/ipykernel_2726021/3536209915.py:111: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not pd.api.types.is_categorical_dtype(adata_5k_i.obs[CATEGORY]):
# /tmp/ipykernel_2726021/3536209915.py:115: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if not pd.api.types.is_categorical_dtype(adata_5k_i.obs[CATEGORY]):
# /tmp/ipykernel_2726021/3536209915.py:128: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_5k_i.obs[CATEGORY] = pd.Categorical(

# %%
all_cell_types = sorted(adata_5k_i.obs["lvl5_annotation"].unique().tolist())
all_cell_types
for x in sorted(adata_5k_i.obs[CATEGORY].unique().tolist()):
    if x not in desired_order2:
        print(x)

# %%
mpl.rcParams["axes.grid"] = False

# %%
desired_order = [ #'Epidermis_APChi', 
     'EpidermisInflamm_upper', 
    'EpidermisInflamm_mid',

        'Epidermis_basal_cycling',
    'Epidermis_upper', 
    
    'Epidermis_mid', 'Epidermis_basal',


    
 'Papillary_dermis',
         'Small_BV',
                  'Tzone-like',

    
 'Reticular_dermis', #'Reticular_dermis_LErich',
                  'Reticular_dermis_LE_rich',


                  'Large_BV', 'VenuleMuscle',
                  'Perineural',
                #  'HF',
               #  'OuterHF',
    'HF_outer', 'HF_inner', #'HF_innermost',
 'Muscle',
 'Sebaceous_gland', 'Sebaceous_duct', 
    'Sebaceous_immune', 
    'Plasma_cell_rich',


   # 'Plasma_cell_niche',


                  'Sweat_gland',
 'Sweat_gland_channel',



# 'Sebaceous_immune',
# 'Epidermis_APChi',
                                   'Hypodermis',

 #'Perifollicular_VE',
 #'Epidermis_basal_immune'
                ]


for x in adata_5k_i.obs[NICHE].unique():
    if x not in desired_order:
        print(x)
desired_order2 = [x for x in desired_order if x in adata_5k_i.obs[NICHE] .unique()]
# Out:
# Epidermis_APChi

# %%
# print("Annotations: ", CATEGORY)

# # ---- Desired row and column order ----
# all_cell_types = sorted(adata_5k_i.obs[CATEGORY].unique().tolist())

# # desired_order = ["NicheA", "NicheC", "NicheB", "NicheZ"]  # your column order

# # Set colormap with grey for NaNs
# cmap = mpl.cm.Reds.copy()
# cmap.set_bad(color='lightgrey')

# for DISEASE in ["AD", "Psoriasis"]:
#     print(DISEASE)
#     adata_5k_iii = adata_5k_i[adata_5k_i.obs["disease_overall"] == DISEASE]
    
#     counts = (
#         adata_5k_iii.obs
#         .groupby([NICHE, CATEGORY])
#         .size()
#         .reset_index(name="count")
#     )
#     heatmap_data = counts.pivot(index=CATEGORY, columns=NICHE, values="count")
#     heatmap_data = heatmap_data.reindex(index=all_cell_types, columns=desired_order).fillna(np.nan)
    

#     heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)


#     # assume heatmap_data, cmap, adata_5k_iii are defined

#     # raw counts
#     col_counts = (
#         adata_5k_iii.obs[NICHE]
#         .value_counts()
#         .reindex(heatmap_data.columns)
#         .fillna(0)
#     )
#     row_counts = (
#         adata_5k_iii.obs[CATEGORY]
#         .value_counts()
#         .reindex(heatmap_data.index)
#         .fillna(0)
#     )

#     # figure + grid
#     fig = plt.figure(figsize=(5
#                               ,10))
#     gs = gridspec.GridSpec(
#         2, 2,
#         height_ratios=[0.2, 4],  # First value controls top bar height (was 1), make it smaller
#         width_ratios=[4, 0.2],   # Second value controls right bar width (was 1), make it smaller
#         hspace=0.05, wspace=0.05
#     )

#     ax_colbar = fig.add_subplot(gs[0,0])
#     ax_empty  = fig.add_subplot(gs[0,1])
#     ax_heat   = fig.add_subplot(gs[1,0])
#     ax_rowbar = fig.add_subplot(gs[1,1])

#     ax_empty.axis('off')

#     # 1) niche12 bar (top), no text
#     x = np.arange(len(col_counts))
#     ax_colbar.bar(x, col_counts.values, color='gray', width=1, align='edge')
#     ax_colbar.set_xlim(0, len(col_counts))
#     ax_colbar.axis('off')

#     # 2) heatmap (no colorbar)
#     sns.heatmap(
#         heatmap_data,
#         cmap=cmap,
#         ax=ax_heat,
#         cbar=False,
#         linewidths=1, #linecolor='white'
#     linecolor=None 
        
#     )
#     ax_heat.set_xlabel('Niche', fontsize=14)
#     ax_heat.set_ylabel('Cell type', fontsize=14)
#     ax_heat.set_xticks(x+0.5)
#     ax_heat.set_xticklabels(heatmap_data.columns, rotation=90, fontsize=12)
#     ax_heat.set_yticks(np.arange(len(heatmap_data.index))+0.5)
#     ax_heat.set_yticklabels(heatmap_data.index, fontsize=12)
#     ax_heat.set_facecolor('white')  # removes background tint behind NaNs
#     # 3) lvl5_annotation bar (right), no text, aligned
#     y = np.arange(len(row_counts))
#     ax_rowbar.barh(y, row_counts.values, color='gray', height=1, align='edge')
#     ax_rowbar.set_ylim(0, len(row_counts))
#     ax_rowbar.invert_yaxis()
#     ax_rowbar.axis('off')

#     plt.tight_layout()
#     plt.savefig(f"./5a_immuneniches_{DISEASE}.pdf", dpi=300, bbox_inches="tight")
#     plt.show()

# %%
print("Annotations: ", CATEGORY)

# ---- Desired row and column order ----
all_cell_types = sorted(adata_5k_i.obs[CATEGORY].unique().tolist())

# desired_order = ["NicheA", "NicheC", "NicheB", "NicheZ"]  # your column order

# Set colormap with grey for NaNs
cmap = mpl.cm.Reds.copy()
cmap.set_bad(color='lightgrey')

for DISEASE in ["AD", "Psoriasis"]:
    print(DISEASE)
    adata_5k_iii = adata_5k_i[adata_5k_i.obs["disease_overall"] == DISEASE]
    
    counts = (
        adata_5k_iii.obs
        .groupby([NICHE, CATEGORY])
        .size()
        .reset_index(name="count")
    )
    heatmap_data = counts.pivot(index=CATEGORY, columns=NICHE, values="count")
    heatmap_data = heatmap_data.reindex(index=all_cell_types, columns=desired_order).fillna(np.nan)
    

    heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)


    # assume heatmap_data, cmap, adata_5k_iii are defined

    # raw counts
    col_counts = (
        adata_5k_iii.obs[NICHE]
        .value_counts()
        .reindex(heatmap_data.columns)
        .fillna(0)
    )
    row_counts = (
        adata_5k_iii.obs[CATEGORY]
        .value_counts()
        .reindex(heatmap_data.index)
        .fillna(0)
    )

    # figure + grid
    fig = plt.figure(figsize=(5
                              ,10))
    gs = gridspec.GridSpec(
        2, 2,
        height_ratios=[0.2, 4],  # First value controls top bar height (was 1), make it smaller
        width_ratios=[4, 0.2],   # Second value controls right bar width (was 1), make it smaller
        hspace=0.05, wspace=0.05
    )

    ax_colbar = fig.add_subplot(gs[0,0])
    ax_empty  = fig.add_subplot(gs[0,1])
    ax_heat   = fig.add_subplot(gs[1,0])
    ax_rowbar = fig.add_subplot(gs[1,1])

    ax_empty.axis('off')

    # 1) niche12 bar (top), no text
    x = np.arange(len(col_counts))
    ax_colbar.bar(x, col_counts.values, color='gray', width=1, align='edge')
    ax_colbar.set_xlim(0, len(col_counts))
    ax_colbar.axis('off')

    # 2) heatmap (no colorbar)
    sns.heatmap(
        heatmap_data,
        cmap=cmap,
        ax=ax_heat,
        cbar=False,
        linewidths=1, 
        linecolor='white'
   # linecolor=None 
        
    )
    ax_heat.set_xlabel('', fontsize=14)
    ax_heat.set_ylabel('', fontsize=14)
    ax_heat.set_xticks(x+0.5)
    ax_heat.set_xticklabels(heatmap_data.columns, rotation=90, fontsize=12)
    ax_heat.set_yticks(np.arange(len(heatmap_data.index))+0.5)
    ax_heat.set_yticklabels(heatmap_data.index, fontsize=12)
    ax_heat.set_facecolor('white')  # removes background tint behind NaNs
    # 3) lvl5_annotation bar (right), no text, aligned
    y = np.arange(len(row_counts))
    ax_rowbar.barh(y, row_counts.values, color='gray', height=1, align='edge')
    ax_rowbar.set_ylim(0, len(row_counts))
    ax_rowbar.invert_yaxis()
    ax_rowbar.axis('off')

    plt.tight_layout()
    plt.savefig(f"./5a_immuneniches__{DISEASE}_grid.pdf", dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# Annotations:  lvl5_annotation
# AD
# /tmp/ipykernel_2726021/926440106.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby([NICHE, CATEGORY])
# /tmp/ipykernel_2726021/926440106.py:93: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Psoriasis
# /tmp/ipykernel_2726021/926440106.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby([NICHE, CATEGORY])
# /tmp/ipykernel_2726021/926440106.py:93: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
IMMUNE_CELLS = adata_5k_i.obs["lvl5_annotation"].unique().tolist()

# %% [markdown]
# # Lesional: Non-immune

# %%
adata_5k_i = adata_5k[          #(adata_5k.obs["Timepoint"].str.startswith("Past"))|

                  
                                            (adata_5k.obs["Site_status"].str.startswith("Les"))
                                                    #  (adata_5k.obs["Site_status"].str.startswith("Never"))|
                      #     (adata_5k.obs["Site_status"].str.startswith("Non"))|
    #   (adata_5k.obs["Site_status"]=="Healthy")
                   ]
#adata_5k.obs["Site_status"].value_counts()
adata_5k_i.obs["Site_status"].value_counts()
# Out:
# Site_status
# Lesional    205777
# Name: count, dtype: int64

# %%
adata_5k_i=adata_5k_i[~adata_5k_i.obs["lvl5_annotation"].isin(IMMUNE_CELLS)]
adata_5k_i.obs["lvl5_annotation"].value_counts()
# adata_5k_i = adata_5k[#(adata_5k.obs["lvl0"].str.startswith("KC"))|
#                      #(adata_5k.obs[CATEGORY].str.startswith("Plasm"))|
#                         (adata_5k.obs["lvl0"].str.startswith("VE"))|
#                      (adata_5k.obs["lvl0"].str.startswith("Fibr"))|
#                      #    (adata_5k.obs["lvl0"]=="KC_Ap") |
#                       (adata_5k.obs["lvl0"]=="Other") 
                      

# #                (adata_5k.obs["lvl0"]=="Melanocyte")|
#  #               (adata_5k.obs["lvl0"]=="Adipocyte")|
#   #             (adata_5k.obs["lvl0"]=="Mast cell")|
#    #                (adata_5k.obs["lvl0"]=="Plasma cell/Bcell")
#                ]
# adata_5k_i=adata_5k_i[adata_5k_i.obs[CATEGORY]!="Plasma cell"]
# adata_5k_i=adata_5k_i[adata_5k_i.obs[CATEGORY]!="Bcell"]
# Out:
# lvl5_annotation
# KC3                               37170
# KC1                               19442
# Pericyte1                         10415
# KC5                               10269
# F1: Superficial                    9617
# F2: Universal                      9101
# VE3_Ven                            8095
# KC1-2_cycling                      6426
# KC2/3_cycling                      4187
# KC                                 4060
# Smooth muscle                      3425
# Sweat gland                        2895
# Pericyte2_VSMC                     2689
# Sweat gland channel outer          2641
# VE1_Art                            2173
# F3: FRC-like                       2104
# Melanocyte                         1909
# LE                                 1788
# nmSchwann                          1758
# VE4_Cap                            1583
# Sweat gland channel inner          1540
# F2/3: Perivascular                 1472
# KCinflamm_basal                    1234
# KC_Sebocyte_DuctOuter              1105
# VE3_Ven_APLN+                       981
# KCinflamm_int/late                  897
# KC_Sebocyte_DuctInner               881
# F5: RAMP1+                          747
# KC_HF: ORS0                         745
# Sweat gland Myoepithelial           661
# F4: DS_DPEP1+                       450
# F4: TNN+COCH+                       414
# KC2                                 406
# F5: NGFR+                           373
# mSchwann                            327
# KC_HF: ORS_junction                 327
# Adipocyte                           284
# KC_HF: ORS2                         264
# KC_Sebocyte_GlandBasal              241
# KC4                                 187
# KC_Sebocyte_DuctInner_Junction      183
# KC_HF: HFSC                         150
# KC_HF: ORS1                         122
# KC_HF: SPON2+                        71
# VE2                                  71
# KC_HF: IRS_Cuticle                   50
# KC_Sebocyte_GlandInner               47
# F4: DP_HHIP+                         26
# Merkel cell                           9
# F6: Inflammatory myofibroblast        6
# KC_HF: IRS1                           3
# KC_HF: IRS0                           2
# Name: count, dtype: int64

# %%
counts = adata_5k_i.obs['niche19'].value_counts()
# 2. Keep only niches with ≥10 cells
keep_niches = counts[counts >= 10].index.tolist()

# 3. Subset your AnnData
adata_5k_i = adata_5k_i[adata_5k_i.obs['niche19'].isin(keep_niches)].copy()

# 4. (Optional) If you want nuisance categories removed entirely:
adata_5k_i.obs['niche19'] = adata_5k_i.obs['niche19'].cat.remove_unused_categories()
adata_5k_i.obs['niche19'].value_counts()
# Out:
# niche19
# Small_BV                    24306
# EpidermisInflamm_mid        23155
# Epidermis_mid               21945
# Epidermis_basal             15065
# Epidermis_upper             14236
# Papillary_dermis            13540
# Reticular_dermis             6002
# Sweat_gland_channel          5192
# Sweat_gland                  4889
# Sebaceous_duct               4655
# Muscle                       4412
# Epidermis_basal_cycling      3907
# Large_BV                     3214
# HF_outer                     2342
# Reticular_dermis_LE_rich     2323
# EpidermisInflamm_upper       2229
# Perineural                   1510
# Tzone-like                   1009
# Hypodermis                    805
# Sebaceous_immune              481
# Sebaceous_gland               382
# Epidermis_APChi               297
# HF_innermost                   56
# VenuleMuscle                   31
# Plasma_cell_rich               23
# HF_inner                       17
# Name: count, dtype: int64

# %%
all_cell_types = sorted(adata_5k_i.obs[CATEGORY].unique().tolist())

# %%
all_cell_types=['Adipocyte',
 'F1: Superficial',
 'F2/3: Perivascular',
 'F2: Universal',
 'F3: FRC-like',
 'F4: DP_HHIP+',
 'F4: DS_DPEP1+',
 'F4: TNN+COCH+',
 'F5: NGFR+',
 'F5: RAMP1+',
 'F6: Inflammatory myofibroblast',
 
 'KC',
 'KC1',
 'KC1-2_cycling',
 'KC2',
 'KC2/3_cycling',
 'KC3',
 'KC4',
 'KC5',
'KCinflamm_basal',
 'KCinflamm_int/late',
 'KC_HF: HFSC',
 'KC_HF: HS',
 'KC_HF: IRS0',
 'KC_HF: IRS1',
 'KC_HF: IRS_Cuticle',
 'KC_HF: Matrix',
 'KC_HF: ORS0',
 'KC_HF: ORS1',
 'KC_HF: ORS2',
 'KC_HF: ORS_cycling',
 'KC_HF: ORS_junction',
 'KC_HF: SPON2+',
 'KC_Sebocyte_DuctInner',
 'KC_Sebocyte_DuctInner_Junction',
 'KC_Sebocyte_DuctOuter',
 'KC_Sebocyte_GlandBasal',
 'KC_Sebocyte_GlandInner',

 'LE',
 'Melanocyte',
 'Merkel cell',
 'Pericyte1',
 'Pericyte2_VSMC',
 'Smooth muscle',
 'Sweat gland',
 'Sweat gland Myoepithelial',
 'Sweat gland channel inner',
 'Sweat gland channel outer',
 'VE1_Art',
 'VE2',
 'VE3_Ven',
 'VE3_Ven_APLN+',
 'VE4_Cap',
 #'beacon_ffpe',
 'mSchwann',
 'nmSchwann']

# %%
print("Annotations: ", CATEGORY)

# ---- Desired row and column order ----

# desired_order = ["NicheA", "NicheC", "NicheB", "NicheZ"]  # your column order

# Set colormap with grey for NaNs
cmap = mpl.cm.Reds.copy()
cmap.set_bad(color='lightgrey')

for DISEASE in ["AD", "Psoriasis"]:
    print(DISEASE)
    adata_5k_iii = adata_5k_i[adata_5k_i.obs["disease_overall"] == DISEASE]
    
    counts = (
        adata_5k_iii.obs
        .groupby([NICHE, CATEGORY])
        .size()
        .reset_index(name="count")
    )
    heatmap_data = counts.pivot(index=CATEGORY, columns=NICHE, values="count")
    heatmap_data = heatmap_data.reindex(index=all_cell_types, columns=desired_order).fillna(np.nan)
    

    heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)


    # assume heatmap_data, cmap, adata_5k_iii are defined

    # raw counts
    col_counts = (
        adata_5k_iii.obs[NICHE]
        .value_counts()
        .reindex(heatmap_data.columns)
        .fillna(0)
    )
    row_counts = (
        adata_5k_iii.obs[CATEGORY]
        .value_counts()
        .reindex(heatmap_data.index)
        .fillna(0)
    )

    # figure + grid
    fig = plt.figure(figsize=(5
                              ,14))
    gs = gridspec.GridSpec(
        2, 2,
        height_ratios=[0.2, 4],  # First value controls top bar height (was 1), make it smaller
        width_ratios=[4, 0.2],   # Second value controls right bar width (was 1), make it smaller
        hspace=0.05, wspace=0.05
    )

    ax_colbar = fig.add_subplot(gs[0,0])
    ax_empty  = fig.add_subplot(gs[0,1])
    ax_heat   = fig.add_subplot(gs[1,0])
    ax_rowbar = fig.add_subplot(gs[1,1])

    ax_empty.axis('off')

    # 1) niche12 bar (top), no text
    x = np.arange(len(col_counts))
    ax_colbar.bar(x, col_counts.values, color='gray', width=1, align='edge')
    ax_colbar.set_xlim(0, len(col_counts))
    ax_colbar.axis('off')

    # 2) heatmap (no colorbar)
    sns.heatmap(
        heatmap_data,
        cmap=cmap,
        ax=ax_heat,
        cbar=False,
        linewidths=1, 
       linecolor='white'
   # linecolor=None 
        
    )
    ax_heat.set_xlabel('', fontsize=14)
    ax_heat.set_ylabel('', fontsize=14)
    ax_heat.set_xticks(x+0.5)
    ax_heat.set_xticklabels(heatmap_data.columns, rotation=90, fontsize=12)
    ax_heat.set_yticks(np.arange(len(heatmap_data.index))+0.5)
    ax_heat.set_yticklabels(heatmap_data.index, fontsize=12)
    ax_heat.set_facecolor('white')  # removes background tint behind NaNs
    # 3) lvl5_annotation bar (right), no text, aligned
    y = np.arange(len(row_counts))
    ax_rowbar.barh(y, row_counts.values, color='gray', height=1, align='edge')
    ax_rowbar.set_ylim(0, len(row_counts))
    ax_rowbar.invert_yaxis()
    ax_rowbar.axis('off')

    plt.tight_layout()
    plt.savefig(f"./5a_{DISEASE}_nonimmuneniches_grid.pdf", dpi=300, bbox_inches="tight")
    plt.show()
# Out:
# Annotations:  lvl5_annotation
# AD
# /tmp/ipykernel_2726021/2831677208.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby([NICHE, CATEGORY])
# /tmp/ipykernel_2726021/2831677208.py:92: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Psoriasis
# /tmp/ipykernel_2726021/2831677208.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby([NICHE, CATEGORY])
# /tmp/ipykernel_2726021/2831677208.py:92: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
