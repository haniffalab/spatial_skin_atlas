# %%
import warnings


warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", RuntimeWarning)

warnings.filterwarnings(
    "ignore",
    category=UserWarning,
    module=r"squidpy\.pl\._spatial_utils"
)

# %%
#import spatialdata as sd
import numpy as np
import pandas as pd
import laris as la


import matplotlib.pyplot as plt
import seaborn as sns

import scanpy as sc
#import squidpy as sq
import anndata as ad

import seaborn as sns
import pickle


from matplotlib.colors import ListedColormap

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
#%matplotlib inline
#sc.settings.figdir = "fig4"
sc.settings.set_figure_params(dpi_save=300, facecolor="white", frameon=False, figsize=(8,8))

# %% [markdown]
# # dotplot of expression

# %%
FILE_NAME = "adata_combined_new.h5ad.final.filtered"
PATH2=f'/nfs/team298/ls34/adult_skin/final_adatas/{FILE_NAME}'
adata_5k=sc.read_h5ad(PATH2)
adata_5k=adata_5k[adata_5k.obs["tech"]=="xenium"]


def remove_markers(LIST):
    try: 
        LIST = {key: [gene for gene in genes if gene in adata_5k.var_names] 
                           for key, genes in LIST.items()}
    except: 
        LIST =[gene for gene in LIST if gene in adata_5k.var_names]
    return LIST

# %%
CATEGORY="lvl5_annotation"
NICHE_COLUMN   = "niche19"
NICHE_COL=NICHE_COLUMN

# %%
sc.pp.normalize_total(adata_5k, target_sum=1e4)
sc.pp.log1p(adata_5k)
# Out:
# /software/cellgen/team298/ls34/ccc_liana/lib/python3.11/site-packages/scanpy/preprocessing/_normalization.py:207: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %% [markdown]
# # Sebaceous gland composition

# %%
# na_counts = (
#     adata_5k.obs
#     .groupby("sample_id")[NICHE_COLUMN]
#     .apply(lambda x: x.isna().sum())
#     .sort_values(ascending=False)
# )

# na_counts.head(5)

# %% [markdown]
# # e9f

# %%
# adata_5k_i = adata_5k[(adata_5k.obs["lvl5_annotation"].str.startswith("Seb"))|
#                        (adata_5k.obs["lvl5_annotation"].str.startswith("KC"))|
#                          (adata_5k.obs["niche19"].str.startswith("Seb"))]
                     

    
    
    
# NICHE="Sebaceous_immune"


# for i, DONOR_ID in enumerate(['BK22_Lesional Baseline',
#  'Lesional_CE4-SKI-27-FO-4-S22-A2',
#  'BK51_wk8 Relapse',
#  'BK25_Week 12', 
#                               #'BK21_Week 12' 
#                              ]  ):
#     adata_i = adata_5k_i[adata_5k_i.obs["info_id6"] == DONOR_ID]
#     #print(adata_i.shape_)
#     #print(i+1, "/", len(samples_to_keep))
#     STATUS = adata_i.obs["Site_status"].unique()[0]
#     TIMEPOINT = adata_i.obs["Timepoint"].unique()[0]
#     DONOR = adata_i.obs["Sanger patient ID"].unique()[0]
#     INFO_ID = list(adata_i.obs.info_id.unique())[0]
#     niche_names_found = adata_i.obs[NICHE_COLUMN].unique()
   
#     if NICHE in niche_names_found:
#         adata_ii = adata_i[adata_i.obs[NICHE_COLUMN] == NICHE]
#         CELL_COUNT = adata_ii.shape[0]
#         print("Cell count for slide: ", CELL_COUNT)
#         print()
#         if CELL_COUNT > 10:
#            # SEB_SAMPLES.append(DONOR_ID)
#             print(DONOR_ID)
#             sq.pl.spatial_scatter(
#                 adata_i,
#                 library_id="spatial",
#                 shape=None,
#                 color=['IL15', "CCL19", 'PNPLA3',],
#                 cmap="Reds", #=palette,
#                 size=1,
#                 vmax=3,
#                 title=['IL15', "CCL19", 'PNPLA3',],
#                 #title=f"{DONOR_ID}_{STATUS}_{TIMEPOINT}_{DONOR}_n={CELL_COUNT}",
#                 edgecolor='black',
#                 linewidth=0.01,
#                 legend_loc=None,
#                 #save=f"sebimmune_nicheonly_{DONOR_ID}.pdf"
#                 # ax=ax,
#                 # legend_loc="on data"
#                 save="supp9d_expression_labelled.pdf"

#             )
       
            
            
# #sc.settings.set_figure_params(dpi=100, facecolor="white", frameon=False, figsize=(18, 18))

# %%
# adata_5k_i = adata_5k[(adata_5k.obs["lvl5_annotation"].str.startswith("Seb"))|
#                        (adata_5k.obs["lvl5_annotation"].str.startswith("KC"))|
#                          (adata_5k.obs["niche19"].str.startswith("Seb"))]
                     

    
    
    
# NICHE="Sebaceous_immune"


# for i, DONOR_ID in enumerate(['BK22_Lesional Baseline',
#  'Lesional_CE4-SKI-27-FO-4-S22-A2',
#  'BK51_wk8 Relapse',
#  'BK25_Week 12', 
#                               #'BK21_Week 12' 
#                              ]  ):
#     adata_i = adata_5k_i[adata_5k_i.obs["info_id6"] == DONOR_ID]
#     #print(adata_i.shape_)
#     #print(i+1, "/", len(samples_to_keep))
#     STATUS = adata_i.obs["Site_status"].unique()[0]
#     TIMEPOINT = adata_i.obs["Timepoint"].unique()[0]
#     DONOR = adata_i.obs["Sanger patient ID"].unique()[0]
#     INFO_ID = list(adata_i.obs.info_id.unique())[0]
#     niche_names_found = adata_i.obs[NICHE_COLUMN].unique()
   
#     if NICHE in niche_names_found:
#         adata_ii = adata_i[adata_i.obs[NICHE_COLUMN] == NICHE]
#         CELL_COUNT = adata_ii.shape[0]
#         print("Cell count for slide: ", CELL_COUNT)
#         print()
#         if CELL_COUNT > 10:

#             sq.pl.spatial_scatter(
#                     adata_i,
#                     library_id="spatial",
#                     shape=None,
#                     color=['IL15', "CCL19", 'PNPLA3',],
#                     cmap="Reds", #=palette,
#                     size=1,
#                     vmax=3,
#                     title=['', '',''],
#                     #title=f"{DONOR_ID}_{STATUS}_{TIMEPOINT}_{DONOR}_n={CELL_COUNT}",
#                     edgecolor='black',
#                     linewidth=0.01,
#                     legend_loc=None,
#                     #save=f"sebimmune_nicheonly_{DONOR_ID}.pdf"
#                     # ax=ax,
#                     # legend_loc="on data"
#                     save="supp9d_expression.pdf"

#                 )

            
# #sc.settings.set_figure_params(dpi=100, facecolor="white", frameon=False, figsize=(18, 18))

# %%
import pickle

file_path = '/nfs/team298/ls34/color_for_adult_skin2.pkl'

with open(file_path, 'rb') as file:
    colors = pickle.load(file)

# %% [markdown]
# # Fig 4c

# %%
# adata_5k_i = adata_5k[(adata_5k.obs["lvl5_annotation"].str.startswith("Seb"))|
#                        (adata_5k.obs["lvl5_annotation"].str.startswith("KC"))|
#                          (adata_5k.obs["niche19"].str.startswith("Seb"))]
                     
                    
# HIGHLIGHT_COLOR = "#ff6145"     # Red, as an example
# OTHER_COLOR = "#ededed"         # Very light grey

# NICHE="Sebaceous_immune"
# #sc.settings.set_figure_params(dpi=100, facecolor="white", frameon=False, figsize=(18, 18))


# #sample_counts = adata_5k_i.obs["info_id6"].value_counts()
# #samples_to_keep = sample_counts[sample_counts > 100].index

# SEB_SAMPLES = []
# for i, DONOR_ID in enumerate(['BK22_Lesional Baseline',
#  'Lesional_CE4-SKI-27-FO-4-S22-A2',
#  'BK51_wk8 Relapse',
#  'BK25_Week 12',  'BK21_Week 12' ]  ):
#     adata_i = adata_5k_i[adata_5k_i.obs["info_id6"] == DONOR_ID]
#     print(i)
#    # print(i+1, "/", len(samples_to_keep))
#     STATUS = adata_i.obs["Site_status"].unique()[0]
#     TIMEPOINT = adata_i.obs["Timepoint"].unique()[0]
#     DONOR = adata_i.obs["Sanger patient ID"].unique()[0]
#     INFO_ID = list(adata_i.obs.info_id.unique())[0]
#     niche_names_found = adata_i.obs[NICHE_COLUMN].unique()
   
#     if NICHE in niche_names_found:
#         adata_ii = adata_i[adata_i.obs[NICHE_COLUMN] == NICHE]
#         CELL_COUNT = adata_ii.shape[0]
#         print("Cell count for slide: ", CELL_COUNT)
#         print()
#         if CELL_COUNT > 10:
#             # 1. Make new obs column
#             adata_i.obs[NICHE_COLUMN + "_highlight"] = adata_i.obs[NICHE_COLUMN].apply(
#                 lambda x: NICHE if x == NICHE else "Other"
#             )
#             # 2. Force categorical with desired order!
#             adata_i.obs[NICHE_COLUMN + "_highlight"] = pd.Categorical(
#                 adata_i.obs[NICHE_COLUMN + "_highlight"],
#                 categories=[NICHE, "Other"],
#                 ordered=True
#             )
#             # 3. Palette as a list, not a dict
#             palette = [HIGHLIGHT_COLOR, OTHER_COLOR]
#             from matplotlib.colors import ListedColormap

#             palette = ListedColormap([HIGHLIGHT_COLOR, OTHER_COLOR])
#             # 4. Plot
#             SEB_SAMPLES.append(DONOR_ID)
#             print(DONOR_ID)
#             sq.pl.spatial_scatter(
#                 adata_i,
#                 library_id="spatial",
#                 shape=None,
#                 color=NICHE_COLUMN + "_highlight",
#                 palette=palette,
#                 size=15,
#                 vmax=1,
#                 title='',
#                 #title=f"{DONOR_ID}_{STATUS}_{TIMEPOINT}_{DONOR}_n={CELL_COUNT}",
#                 edgecolor='black',
#                 linewidth=0.02,
#                 legend_loc=None,
#                 save=f"4e_sebimmune_nicheonly_{DONOR_ID}.pdf"
#                 # ax=ax,
#                 # legend_loc="on data"
#             )

# %%
CORE_PAPER = ['BK22_Lesional Baseline',
# 'Lesional_CE4-SKI-27-FO-4-S22_replicate',
               'BK51_wk8 Relapse',
 'BK25_Week 12',

 'Lesional_CE4-SKI-27-FO-4-S22-A2',

 #'BK30_Week 12',
 #'BK18_Lesional Baseline',
 #'BK30_Non-lesional Baseline',
 #'BK30_Lesional Baseline',
 #'BK24_Non-lesional Baseline',
 #'BK21_Week 12'
             
             
             ]

# %%
HIGHLIGHT_COLOR = "#ff6145"     # Red, as an example
OTHER_COLOR = "#ededed"         # Very light grey

NICHE="Sebaceous_immune"
#sc.settings.set_figure_params(dpi=100, facecolor="white", frameon=False, figsize=(18, 18))

adata_5k_i = adata_5k  # Filter as you need

sample_counts = adata_5k_i.obs["info_id6"].value_counts()
#samples_to_keep = sample_counts[sample_counts > 100].index

SEB_SAMPLES = []
adata_ii = adata_5k_i[adata_5k_i.obs["info_id6"] == 'BK22_Lesional Baseline']
# Out:
# 0
# Cell count for slide:  961
#
# BK22_Lesional Baseline
# /tmp/ipykernel_235909/4177777533.py:30: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_i.obs[NICHE_COLUMN + "_highlight"] = adata_i.obs[NICHE_COLUMN].apply(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 47
#      45         SEB_SAMPLES.append(DONOR_ID)
#      46         print(DONOR_ID)
# ---> 47         sq.pl.spatial_scatter(
#      48             adata_i,
#      49             library_id="spatial",
#      50             shape=None,
#      51             color=NICHE_COLUMN + "_highlight",
#      52             palette=palette,
#      53             size=8,
#      54             vmax=1,
#      55             title='',
#      56             #title=f"{DONOR_ID}_{STATUS}_{TIMEPOINT}_{DONOR}_n={CELL_COUNT}",
#      57             edgecolor='black',
#      58             linewidth=0.05,
#      59             legend_loc=None,
#      60             #save=f"4a_sebimmune_nicheonly_{DONOR_ID}.pdf"
#      61             # ax=ax,
#      62             # legend_loc="on data"
#      63         )
#      64 if i ==0:
#      65     break
#
# NameError: name 'sq' is not defined

# %%
lr_df=pd.read_csv('/nfs/team298/ls34/dicts/human_lr_database_CellChatDB_formatted_v2.csv')

# %%
adata_ii
# Out:
# View of AnnData object with n_obs × n_vars = 961 × 4993
#     obs: 'sample_id', 'barcode', 'GSE', 'Site_status', 'Patient_status', 'Location', 'Age', 'Sex', 'n_genes', 'dataset_id', 'n_genes_by_counts', 'total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'QC_hi', 'QC_mid', 'lvl5_annotation', 'Mapping_status', 'scanvi_predictions', 'lvl5_annotation_new', 'lvl5_annotation_new2', 'lvl5_annotation_new3', 'lvl5_annotation_new_archive', 'lvl5_annotation_new_preoprhan', 'lvl5_annotation_new10', 'lvl5_annotation_new11', 'test', 'test_n', 'lvl5_annotation_new12', 'lvl5_annotation_new13', 'lvl4_annotation', 'lvl0', 'temp', 't', 'leiden_res0.1', 'Site_status_simple', 'StatusMilo', 'atlas_status', 'atlas_status_reynolds', 'atlas_status_reynolds_simple', 'atlas_status_simple', 'atlas_status_simple2', 'Site_status_binary', 'scanvi_labels', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'xenium_id', 'xenium_id_recoded', 'GSTT patient ID', 'Sanger patient ID', 'Drug', 'Responder', 'Timepoint', "Library type (CITE or 5'GEX/TCR)", 'Segmentation Y/N?', 'Sample ID', 'Xenium slide number', 'Xenium region number2', 'baseline_postrx', 'info_id', 'Annotation', 'NICHE_NAMES', 'batch', 'DonorID', 'leiden_res1', 'leiden_res2', 'new_annotation', 'new_annotation2', 'new_annotation3', 'annotation_new4', 'new_annotation4', 'new_annotation5', 'new_annotation6', 'sample', 'niche_name', 'veryfine_celltypes_new', 'niche_category', 'veryfine_celltypes_new2', 'lvl1', 'veryfine_celltypes_new3', 'veryfine_celltypes_new4', 'veryfine_celltypes_new5', 'veryfine_celltypes_new5_incprolif', 'veryfine_celltypes', 'fine_celltypes_new', 'mod_celltypes_new', 'broad_celltypes_new', 'number', 'lvl3_annotation', 'disease_overall', 'lvl0_annotation', 'lvl0_annotation2', 'lvl1_annotation', 'lvl1_annotation2', 'lvl1_annotation3', 'lvl1_annotation4', 'lvl1_annotation5', 'lvl1_annotation6', 'lvl1_annotation7', 'lvl1_annotation8', 'lvl2_annotation9', 'Annotation_tomap', 'leiden_res3', 'lvl3_annotation3', 'lvl3_annotation4', 'lvl3_annotation5', 'combined_annotation', 'combined_annotation2', 'lvl0_new', 'combined_annotation3', 'combined_annotation4', 'combined_annotation6', 'combined_annotation7', 'combined_annotation8', 'combined_annotation9', 'final_annotation', 'final_annotation2', 'final_annotation3', 'final_annotation4', 'final_annotation5', 'final_annotation7', 'final_annotation8', 'final_annotation9', 'final_annotation10', 'final_annotation_lvl5temp', 'niche_names', 'niche10', 'info_id2', 'final_annotation_lvl4', 'final_annotation_lvl3', 'niche11', 'final_annotation5_3', 'final_annotation5_2', 'final_annotation_lvl5_4', 'FinalXeniumScanVI_14', 'FinalXeniumScanVI_16', 'FinalXeniumScanVI_17', 'niche12', 'lvl2_annotation', 'Timepoint2', 'updatenames1', 'updatenames2', 'updatenames3', 'lvl5_annotation_new4', 'lvl5_annotation_new5', 'lvl5_annotation_new_preophan', 'lvl5_annotation_new9', 'baseline_severity', 'lvl4_annotation_sept', 'info_id6', 'prep', 'Site_status_archive', 'response', 'response_binned', 'xenium_id_recoded2', 'RUN_ID', 'newintegration', 'leiden_res0.2', 'replicate_id', 'fig8_mapping', 'all_vs_core', 'scanvi_predictions_new', 'leiden_res0.1_2', 'niche14', 'tech', 'scanvi_predictions2', 'leiden_res0.5', 'provisional', 'labels_0', 'labels_1', 'labels_2', 'labels_3', 'labels_4', 'labels_5', 'labels_6', 'labels_7', 'labels_8', 'labels_9', 'labels_10', 'final_labels', 'final_labels2', 'final_labels3', 'final_labels4', 'labels_11', 'labels_12', 'labels_13', 'labels_14', 'labels_15', 'labels_16', 'labels_17' ...
#     uns: 'leiden', 'leiden_res0.1', 'lvl5_annotation_colors', 'lvl6_annotation_colors', 'neighbor_10', 'niche14_colors', 'niche19_colors', 'provisional_colors', 'scanvi_predictions2_colors', 'tech_colors', 'test_colors', 'umap', 'log1p'
#     obsm: 'X_scvi', 'X_umap', 'spatial'
#     layers: 'counts'
#     obsp: 'neighbor_10_connectivities', 'neighbor_10_distances'

# %%
rows_keep=np.logical_and( lr_df['ligand'].isin(adata_ii.var_names), lr_df['receptor'].isin(adata_ii.var_names) )

# %%
lr_df=lr_df.loc[rows_keep].copy()

# %%
lr_adata=la.tl.prepareLRInteraction(
    adata_ii, # object used to construt the LR object
    lr_df, # dataframe to use for interactions
    number_nearest_neighbors=20,
    use_rep_spatial='spatial'
)

# %%
adata_ii
# Out:
# View of AnnData object with n_obs × n_vars = 961 × 4993
#     obs: 'sample_id', 'barcode', 'GSE', 'Site_status', 'Patient_status', 'Location', 'Age', 'Sex', 'n_genes', 'dataset_id', 'n_genes_by_counts', 'total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'QC_hi', 'QC_mid', 'lvl5_annotation', 'Mapping_status', 'scanvi_predictions', 'lvl5_annotation_new', 'lvl5_annotation_new2', 'lvl5_annotation_new3', 'lvl5_annotation_new_archive', 'lvl5_annotation_new_preoprhan', 'lvl5_annotation_new10', 'lvl5_annotation_new11', 'test', 'test_n', 'lvl5_annotation_new12', 'lvl5_annotation_new13', 'lvl4_annotation', 'lvl0', 'temp', 't', 'leiden_res0.1', 'Site_status_simple', 'StatusMilo', 'atlas_status', 'atlas_status_reynolds', 'atlas_status_reynolds_simple', 'atlas_status_simple', 'atlas_status_simple2', 'Site_status_binary', 'scanvi_labels', 'cell_id', 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'xenium_id', 'xenium_id_recoded', 'GSTT patient ID', 'Sanger patient ID', 'Drug', 'Responder', 'Timepoint', "Library type (CITE or 5'GEX/TCR)", 'Segmentation Y/N?', 'Sample ID', 'Xenium slide number', 'Xenium region number2', 'baseline_postrx', 'info_id', 'Annotation', 'NICHE_NAMES', 'batch', 'DonorID', 'leiden_res1', 'leiden_res2', 'new_annotation', 'new_annotation2', 'new_annotation3', 'annotation_new4', 'new_annotation4', 'new_annotation5', 'new_annotation6', 'sample', 'niche_name', 'veryfine_celltypes_new', 'niche_category', 'veryfine_celltypes_new2', 'lvl1', 'veryfine_celltypes_new3', 'veryfine_celltypes_new4', 'veryfine_celltypes_new5', 'veryfine_celltypes_new5_incprolif', 'veryfine_celltypes', 'fine_celltypes_new', 'mod_celltypes_new', 'broad_celltypes_new', 'number', 'lvl3_annotation', 'disease_overall', 'lvl0_annotation', 'lvl0_annotation2', 'lvl1_annotation', 'lvl1_annotation2', 'lvl1_annotation3', 'lvl1_annotation4', 'lvl1_annotation5', 'lvl1_annotation6', 'lvl1_annotation7', 'lvl1_annotation8', 'lvl2_annotation9', 'Annotation_tomap', 'leiden_res3', 'lvl3_annotation3', 'lvl3_annotation4', 'lvl3_annotation5', 'combined_annotation', 'combined_annotation2', 'lvl0_new', 'combined_annotation3', 'combined_annotation4', 'combined_annotation6', 'combined_annotation7', 'combined_annotation8', 'combined_annotation9', 'final_annotation', 'final_annotation2', 'final_annotation3', 'final_annotation4', 'final_annotation5', 'final_annotation7', 'final_annotation8', 'final_annotation9', 'final_annotation10', 'final_annotation_lvl5temp', 'niche_names', 'niche10', 'info_id2', 'final_annotation_lvl4', 'final_annotation_lvl3', 'niche11', 'final_annotation5_3', 'final_annotation5_2', 'final_annotation_lvl5_4', 'FinalXeniumScanVI_14', 'FinalXeniumScanVI_16', 'FinalXeniumScanVI_17', 'niche12', 'lvl2_annotation', 'Timepoint2', 'updatenames1', 'updatenames2', 'updatenames3', 'lvl5_annotation_new4', 'lvl5_annotation_new5', 'lvl5_annotation_new_preophan', 'lvl5_annotation_new9', 'baseline_severity', 'lvl4_annotation_sept', 'info_id6', 'prep', 'Site_status_archive', 'response', 'response_binned', 'xenium_id_recoded2', 'RUN_ID', 'newintegration', 'leiden_res0.2', 'replicate_id', 'fig8_mapping', 'all_vs_core', 'scanvi_predictions_new', 'leiden_res0.1_2', 'niche14', 'tech', 'scanvi_predictions2', 'leiden_res0.5', 'provisional', 'labels_0', 'labels_1', 'labels_2', 'labels_3', 'labels_4', 'labels_5', 'labels_6', 'labels_7', 'labels_8', 'labels_9', 'labels_10', 'final_labels', 'final_labels2', 'final_labels3', 'final_labels4', 'labels_11', 'labels_12', 'labels_13', 'labels_14', 'labels_15', 'labels_16', 'labels_17' ...
#     uns: 'leiden', 'leiden_res0.1', 'lvl5_annotation_colors', 'lvl6_annotation_colors', 'neighbor_10', 'niche14_colors', 'niche19_colors', 'provisional_colors', 'scanvi_predictions2_colors', 'tech_colors', 'test_colors', 'umap', 'log1p'
#     obsm: 'X_scvi', 'X_umap', 'spatial'
#     layers: 'counts'
#     obsp: 'neighbor_10_connectivities', 'neighbor_10_distances'

# %%
import warnings
warnings.filterwarnings("ignore")
LARIS_variable_interactions, res_LARIS=la.tl.runLARIS(
    lr_adata,
    adata_ii,
    use_rep='spatial',
    n_nearest_neighbors=20,
    random_seed=27,
    n_repeats=5,
    mu = 0.40, # larger value indicates more consideration for specificity
    sigma=100,
    remove_lowly_expressed=False,
    expressed_pct=0.1,
    n_cells_expressed_threshold=100,
    n_top_lr=lr_adata.shape[1],

    by_celltype=True,
    ### Parameters for cell type-level inference when by_celltype set to True
    groupby='lvl5_annotation', # label to group by
    use_rep_spatial='spatial', # spatial coordinates
    mu_celltype=100, # higher value puts more emphasis on cell type specificity
    expressed_pct_celltype=0.1, # expression percentage cut off per cell type
    remove_lowly_expressed_celltype=False,
    mask_threshold=1e-6, # mask for cosg, lower value is less restrictive
    n_neighbors_permutation=30,
    score_threshold= 1e-10,
    spatial_weight = 3.0,
)
# Out:
# ======================================================================
# LARIS ANALYSIS
# ======================================================================
#
# Input data: 961 cells × 1147 LR pairs
# Mode: Cell type-specific analysis
#
# --- Step 1: Calculating spatial specificity scores ---
#   - Using 20 nearest neighbors
#   - Regularization parameter μ = 0.4
#   - Random repeats: 5
#   - Generating random permutations...
#   ✓ Identified 1147 top spatially-specific LR pairs
#   - Score range: [-0.0230, 0.7770]
#
# ======================================================================
# CELL TYPE-SPECIFIC ANALYSIS
# ======================================================================
#
# Analyzing 35 cell types from 'lvl5_annotation'
# Cell types: ['ILC1', 'ILC2', 'ILC3_CCL1+PTGDS+', 'KC1', 'KC1-2_cycling', 'KC2/3_cycling', 'KC3', 'KC_Sebocyte_DuctInner_Junction', 'KC_Sebocyte_DuctOuter', 'KCinflamm_basal']...
#
# ======================================================================
# LARIS CELL TYPE ANALYSIS
# ======================================================================
#
# --- Step 1: Calculating ligand and receptor cell type specificity ---
#   ✓ Computed specificity for 733 genes across 35 cell types
#
# --- Step 2: Calculating diffused LR-score distribution ---
#   ✓ Computed diffused scores for 1147 interactions
#
# --- Step 3: Computing interaction scores (spatial_weight=3.0) ---
#   ✓ Processed 1147 interactions
#
# --- Step 3.5: Rescaling interaction scores ---
#   - Scaling factor: 0.049907 (based on top 100 scores)
#
# --- Step 4: Incorporating spatial cell type co-localization ---
#   ✓ Calculated co-localization for 1147 interactions and 1225 sender-receiver pairs
#   ✓ Applied co-localization weights
#
# --- Step 4.5: Cleaning up numerical precision (threshold=1e-10) ---
#   - Before: 1,335,579 scores < threshold, 1,313,141 exactly zero
#   - After: 1,335,579 scores set to exactly 0.0
#
# ======================================================================
# STATISTICAL SIGNIFICANCE TESTING
# ======================================================================
#
# --- Step 5.1: Preparing background interaction sets ---
#   - Calculating summary statistics for 1147 interactions...
#   - Building KDTree to find 30 nearest neighbors...
#   - Background set prepared: 1147 interactions
#
# --- Step 5.2: Calculating p-values (1,000 permutations) ---
#   - Method: Standard
#   - Chunk size: 50,000
#   - Testing 1225 sender-receiver pairs
#   Processing pairs: 100%|██████████| 1225/1225 [08:50<00:00,  2.31it/s]
#   ✓ Calculated p-values for 1,405,075 interaction combinations
#
# --- Step 5.3: Applying FDR correction (Benjamini-Hochberg) ---
#   - Strategy: Pre-filtered
#   - Pre-filter threshold: 0.0
#   FDR correction: 100%|██████████| 1225/1225 [00:01<00:00, 749.34it/s]
#   ✓ Corrected 1225 sender-receiver pairs
#   - Interactions tested: 69,496
#   - Interactions filtered: 1,335,579
#
#   Significant interactions:
#   - FDR < 0.05: 6,537 (0.47%)
#   - FDR < 0.01: 3,047 (0.22%)
#
# ======================================================================
# STATISTICAL TESTING COMPLETE
# ======================================================================
#
# ======================================================================
# LARIS CELL TYPE ANALYSIS COMPLETE
# ======================================================================
#
# Final results: 1,405,075 sender-receiver-LR combinations
# Score range: [0.000000, 1.087465]
#
# ======================================================================
# ANALYSIS COMPLETE
# ======================================================================
#
# Results summary:
#   - Spatially-specific LR pairs: 1147
#   - Cell type combinations: 1,405,075
#   - Significant interactions (FDR < 0.05): 6,537

# %%
sc.pl.dotplot(lr_adata,
              LARIS_variable_interactions.index[:10],
              groupby='niche19',
             standard_scale='var',
             cmap='Spectral_r')

# %%
sc.pl.dotplot(lr_adata,
              LARIS_variable_interactions.index[:10],
              groupby='lvl5_annotation',
             standard_scale='var',
             cmap='Spectral_r')

# %%
x_width=adata_ii.obsm['spatial'][:,0].max()-adata_ii.obsm['spatial'][:,0].min()
y_width=adata_ii.obsm['spatial'][:,1].max()-adata_ii.obsm['spatial'][:,1].min()

plt.rcParams['figure.figsize'] = 2.5, 2.5*y_width/x_width

sc.pl.embedding(
    lr_adata,
    basis='spatial',
    color=LARIS_variable_interactions.index[:8],
   # cmap=pos_cmap,
 #   vmin=1,
  #  vmax=1.5,
      # palette=self_palette2,
       ncols=4,
    cmap="Reds",
    size=10,
    frameon=False)
plt.rcParams['figure.figsize'] = 4, 4

# %%
import cosg

# %%
n_gene=30 # number of genes to save
groupby='niche19'
cosg.cosg(lr_adata,
    key_added='cosg',
    mu=100,
    expressed_pct=0.15, # minimum % of expression to make cut off
    remove_lowly_expressed=True,
    n_genes_user=100, # How many genes to append
    groupby=groupby)

# %%
# sc.tl.dendrogram(lr_adata, groupby=groupby, use_rep='X_pca')
df_tmp=pd.DataFrame(lr_adata.uns['cosg']['names'][:20,]).T
#df_tmp=df_tmp.reindex(lr_adata.uns['dendrogram_'+groupby]['categories_ordered'])
marker_genes_list={idx: list(row.values) for idx, row in df_tmp.iterrows()}
marker_genes_list = {k: v for k, v in marker_genes_list.items() if not any(isinstance(x, float) for x in v)}

# %%
sc.pl.dotplot(lr_adata, marker_genes_list,
             groupby=groupby,
             #dendrogram=True,
            swap_axes=False,
             standard_scale='var',
             cmap='Spectral_r')

# %%
x_width=adata.obsm['X_spatial'][:,0].max()-adata.obsm['X_spatial'][:,0].min()
y_width=adata.obsm['X_spatial'][:,1].max()-adata.obsm['X_spatial'][:,1].min()

plt.rcParams['figure.figsize'] = 2.5, 2.5*y_width/x_width

sc.pl.embedding(
    lr_adata,
    basis='spatial',
    color=['BMP7::BMPR1A','IL21::IL21R','FCER2::CR2','CCL19::CCR7'],
    cmap=pos_cmap,
    ncols=4,
    # size=120,
    frameon=False)
plt.rcParams['figure.figsize'] = 4, 4

# %%
# x_width=adata.obsm['X_spatial'][:,0].max()-adata.obsm['X_spatial'][:,0].min()
# y_width=adata.obsm['X_spatial'][:,1].max()-adata.obsm['X_spatial'][:,1].min()

# plt.rcParams['figure.figsize'] = 2.5, 2.5*y_width/x_width

# sc.pl.embedding(
#     lr_adata,
#     basis='X_umap',
#     color=['BMP7::BMPR1A','IL21::IL21R','FCER2::CR2','CCL19::CCR7'],
#     cmap=pos_cmap,
#     ncols=4,
#     # size=60,
#     frameon=False)
# plt.rcParams['figure.figsize'] = 4, 4

# %%
fig=la.pl.plotCCCHeatmap(
    res_LARIS,
    cmap='plasma',
    filter_significant=False,
    n_top=20,
)

# %%
adata_ii= adata_5k_i[adata_5k_i.obs["info_id6"] == 'Lesional_CE4-SKI-27-FO-4-S22-A2',].copy()

# %%
rows_keep=np.logical_and( lr_df['ligand'].isin(adata_ii.var_names), lr_df['receptor'].isin(adata_ii.var_names) )

lr_df=lr_df.loc[rows_keep].copy()

lr_adata=la.tl.prepareLRInteraction(
    adata_ii, # object used to construt the LR object
    lr_df, # dataframe to use for interactions
    number_nearest_neighbors=20,
    use_rep_spatial='spatial'
)
import warnings
warnings.filterwarnings("ignore")

# %%
LARIS_variable_interactions, res_LARIS=la.tl.runLARIS(
    lr_adata,
    adata_ii,
    use_rep='spatial',
    n_nearest_neighbors=20,
    random_seed=27,
    n_repeats=5,
    mu = 0.40, # larger value indicates more consideration for specificity
    sigma=100,
    remove_lowly_expressed=False,
    expressed_pct=0.1,
    n_cells_expressed_threshold=100,
    n_top_lr=lr_adata.shape[1],

    by_celltype=True,
    ### Parameters for cell type-level inference when by_celltype set to True
    groupby='lvl5_annotation', # label to group by
    use_rep_spatial='spatial', # spatial coordinates
    mu_celltype=100, # higher value puts more emphasis on cell type specificity
    expressed_pct_celltype=0.1, # expression percentage cut off per cell type
    remove_lowly_expressed_celltype=False,
    mask_threshold=1e-6, # mask for cosg, lower value is less restrictive
    n_neighbors_permutation=30,
    score_threshold= 1e-10,
    spatial_weight = 3.0,
)
# Out:
# ======================================================================
# LARIS ANALYSIS
# ======================================================================
#
# Input data: 20471 cells × 1147 LR pairs
# Mode: Cell type-specific analysis
#
# --- Step 1: Calculating spatial specificity scores ---
#   - Using 20 nearest neighbors
#   - Regularization parameter μ = 0.4
#   - Random repeats: 5
#   - Generating random permutations...
#   ✓ Identified 1147 top spatially-specific LR pairs
#   - Score range: [-0.0159, 0.8872]
#
# ======================================================================
# CELL TYPE-SPECIFIC ANALYSIS
# ======================================================================
#
# Analyzing 90 cell types from 'lvl5_annotation'
# Cell types: ['Adipocyte', 'Bcell', 'F1: Superficial', 'F2/3: Perivascular', 'F2: Universal', 'F3: FRC-like', 'F4: DP_HHIP+', 'F4: DS_DPEP1+', 'F4: TNN+COCH+', 'F5: NGFR+']...
#
# ======================================================================
# LARIS CELL TYPE ANALYSIS
# ======================================================================
#
# --- Step 1: Calculating ligand and receptor cell type specificity ---
#   ✓ Computed specificity for 733 genes across 90 cell types
#
# --- Step 2: Calculating diffused LR-score distribution ---
#   ✓ Computed diffused scores for 1147 interactions
#
# --- Step 3: Computing interaction scores (spatial_weight=3.0) ---
#   ✓ Processed 1147 interactions
#
# --- Step 3.5: Rescaling interaction scores ---
#   - Scaling factor: 0.036155 (based on top 100 scores)
#
# --- Step 4: Incorporating spatial cell type co-localization ---
#   ✓ Calculated co-localization for 1147 interactions and 8100 sender-receiver pairs
#   ✓ Applied co-localization weights
#
# --- Step 4.5: Cleaning up numerical precision (threshold=1e-10) ---
#   - Before: 8,970,843 scores < threshold, 8,662,537 exactly zero
#   - After: 8,970,843 scores set to exactly 0.0
#
# ======================================================================
# STATISTICAL SIGNIFICANCE TESTING
# ======================================================================
#
# --- Step 5.1: Preparing background interaction sets ---
#   - Calculating summary statistics for 1147 interactions...
#   - Building KDTree to find 30 nearest neighbors...
#   - Background set prepared: 1147 interactions
#
# --- Step 5.2: Calculating p-values (1,000 permutations) ---
#   - Method: Standard
#   - Chunk size: 50,000
#   - Testing 8100 sender-receiver pairs
#   Processing pairs:  26%|██▌       | 2101/8100 [15:06<43:32,  2.30it/s]

# %%
sc.pl.dotplot(lr_adata,
              LARIS_variable_interactions.index[:10],
              groupby='niche19',
             standard_scale='var',
             cmap='Spectral_r')

# %%
x_width=adata_ii.obsm['spatial'][:,0].max()-adata_ii.obsm['spatial'][:,0].min()
y_width=adata_ii.obsm['spatial'][:,1].max()-adata_ii.obsm['spatial'][:,1].min()

plt.rcParams['figure.figsize'] = 2.5, 2.5*y_width/x_width

sc.pl.embedding(
    lr_adata,
    basis='spatial',
    color=LARIS_variable_interactions.index[:8],
   # cmap=pos_cmap,
 #   vmin=1,
  #  vmax=1.5,
      # palette=self_palette2,
       ncols=4,
    cmap="Reds",
    size=10,
    frameon=False)
plt.rcParams['figure.figsize'] = 4, 4

# %%
n_gene=30 # number of genes to save
groupby='niche19'
cosg.cosg(lr_adata,
    key_added='cosg',
    mu=100,
    expressed_pct=0.15, # minimum % of expression to make cut off
    remove_lowly_expressed=True,
    n_genes_user=100, # How many genes to append
    groupby=groupby)

# %%
# sc.tl.dendrogram(lr_adata, groupby=groupby, use_rep='X_pca')
df_tmp=pd.DataFrame(lr_adata.uns['cosg']['names'][:20,]).T
#df_tmp=df_tmp.reindex(lr_adata.uns['dendrogram_'+groupby]['categories_ordered'])
marker_genes_list={idx: list(row.values) for idx, row in df_tmp.iterrows()}
marker_genes_list = {k: v for k, v in marker_genes_list.items() if not any(isinstance(x, float) for x in v)}

# %%
sc.pl.dotplot(lr_adata, marker_genes_list,
             groupby=groupby,
             #dendrogram=True,
            swap_axes=False,
             standard_scale='var',
             cmap='Spectral_r')

# %%
90
